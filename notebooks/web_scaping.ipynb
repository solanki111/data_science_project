# %%
# import
import requests
from bs4 import BeautifulSoup

# %%
# HTML String
html_string = """
<!DOCTYPE html>
<html lang='en' dir='ltr' style='padding: 0; margin: 0;'>
   <head>
      <meta http-equiv='Content-Type' content='text/html; charset=utf-8' />
      <link rel='icon' href='https://qsf.fs.quoracdn.net/-4-images.favicon.ico-26-ebf6a9e7f7b4576d.ico' />
      <title>How to prepare for a data scientist interview - Quora</title>
      <meta name="robots" content="noarchive" />
      <meta name='twitter:widgets:theme' content='light' />
      <link rel='canonical' href='https://www.quora.com/How-do-I-prepare-for-a-data-scientist-interview' />
      <link as='script' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ac99ceb1b9c10014.webpack' />
      <link as='script' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-15b26220d3ee4250.webpack' />
      <link as='script' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-27-847dd7e3d7f6b8cc.webpack' />
      <link as='script' rel='preload' href='https://connect.facebook.net/en_US/sdk.js' />
      <link as='style' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-main.css-28-c9124fa2d576a546.webpack' />
      <link rel='stylesheet' type='text/css' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-main.css-28-c9124fa2d576a546.webpack' id='ans-frontend-main-css' />
      <script type="text/javascript">window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"common":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ac99ceb1b9c10014.webpack","component-AdCTABanner":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-4b8fca9243f93aba.webpack","component-AdminTools-profile":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-f94ba2e45814a14d.webpack","component-AnswerEditor":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-AnswerEditor-27-6b5ed2d6266ff1ec.webpack","component-AnswerPageFooter":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-9e4aaef8be68f99b.webpack","component-Comments":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-1da92ab58f49ee46.webpack","component-Hovercards":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-b135621a6be6f733.webpack","component-Login":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Login-27-5612fbdcc9d7063a.webpack","component-MobileLookup":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-19f7008fca1d56a7.webpack","component-Modals-AdsConsumer":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-69ab597f8c145068.webpack","component-Modals-AdsManager":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-3630fa4c6f937b78.webpack","component-Modals-AskQuestion":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-5d16741db2d931d4.webpack","component-Modals-Business":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-Business-27-08e8279e0e091908.webpack","component-Modals-EarningsPrograms":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-EarningsPrograms-27-1788fe6d477947fc.webpack","component-Modals-Editor":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-Editor-27-2c558841ae94c3a7.webpack","component-Modals-NUX":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-NUX-27-d842a9796d82708b.webpack","component-Modals-Topics":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-Topics-27-05184816674fcf30.webpack","component-Modals-TribeTab":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-TribeTab-27-0ef85d5d4665692f.webpack","component-Modals-answer":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-answer-27-90999827da8f6609.webpack","component-Modals-credentials":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-credentials-27-506957c14ef16102.webpack","component-Modals-feed":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-feed-27-88a42b800924b3dd.webpack","component-Modals-others":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-others-27-fcc13011b4ea53e1.webpack","component-Modals-pageFlows":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-pageFlows-27-f0215c1558e1b1ac.webpack","component-Modals-question":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-question-27-f5bcfd841c250dfd.webpack","component-Modals-share":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-share-27-c3876198bb487ca5.webpack","component-Modals-subscriptions":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-subscriptions-27-dec018670cc4f4a0.webpack","component-Modals-tribe":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-tribe-27-ae71509a92342324.webpack","component-Multifeed":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-component-
oadable":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-WriterEarningsDashboardLoadable-27-c1f50c3f3575df3e.webpack","page-WriterManageMonetizedAnswersLoadable":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-WriterManageMonetizedAnswersLoadable-27-5f3e05000eaa43b2.webpack","polyfills":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-polyfills-27-8faf3b7a54f97e24.webpack","ssr":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-ssr-27-695bd20c118d4364.webpack","vendor":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-27-847dd7e3d7f6b8cc.webpack","vendor-AdsManager-BusinessServices":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-AdsManager-BusinessServices-27-01dc532d61a438b7.webpack","vendor-component-Modals-AdsManager":"https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-component-Modals-AdsManager-27-8f5ff43b88082840.webpack"};
         var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
         window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-QuestionPageLoadable"]);
      </script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settingsStrictMode = false;</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "8899b542a65416db9195d943e35d34a1", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "topLevelNid": 0, "react_console_log_perf_info": false, "windowId": "react_vpopiagoqpmcidij", "rootClsKey": "QuestionPage", "rootQueryVariables": {"url": "https://www.quora.com/How-do-I-prepare-for-a-data-scientist-interview", "redirectedQid": 0, "topAid": null, "first": 5}, "rootProps": {"isFromQuestionStory": false}, "inlineQueryEnabled": true, "inlineQueryHashes": {"eb7559536836f1916597ee60bf5dd5e69724c90b2efd896a1438bad151872fdf": true, "2f873aed85d7270c58b44eeb7ee01e5cfc8bd4cc6ce6018b93840a89ffc1c155": true, "95f35eb8a38fee5ed862eedc4d9c347516661a2d7bd1f5e70bd1767f9af15d4c": true}, "isPageShell": false, "pageShellInfo": null, "earlyQueryRequestEnabled": false, "shouldServerRender": false};</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = {"inlineQueryResults": {}};</script><script type="text/javascript" id="entryjs">!function(t){function e(e){for(var n,o,i=e[0],u=e[1],a=0,c=[];a<i.length;a++)o=i[a],Object.prototype.hasOwnProperty.call(r,o)&&r[o]&&c.push(r[o][0]),r[o]=0;for(n in u)Object.prototype.hasOwnProperty.call(u,n)&&(t[n]=u[n]);for(s&&s(e);c.length;)c.shift()()}var n={},r={entry:0};function o(t){return window.ansFrontendRelayWebpackManifest[t]}function i(e){if(n[e])return n[e].exports;var r=n[e]={i:e,l:!1,exports:{}};return t[e].call(r.exports,r,r.exports,i),r.l=!0,r.exports}i.e=function(t){if(0===r[t])return Promise.resolve();if(r[t])return r[t][2];var e=new Promise((function(e,n){r[t]=[e,n]}));if(r[t][2]=e,-1!=window.ansFrontendRelayWebpackIncludedChunks.indexOf(t))return e;var n=document.getElementsByTagName("head")[0];(a=document.createElement("script")).charset="utf-8",a.timeout=120,i.nc&&a.setAttribute("nonce",i.nc),a.src=o(t);var u=new Error;c=function(e){a.onerror=a.onload=null,clearTimeout(s);var n=r[t];if(0!==n){if(n){var o=e&&("load"===e.type?"missing":e.type),i=e&&e.target&&e.target.src;u.message="Loading chunk "+t+" failed.\n("+o+": "+i+")",u.name="ChunkLoadError",u.type=o,u.request=i,n[1](u)}r[t]=undefined}};var a,c,s=setTimeout((function(){c({type:"timeout",target:a})}),12e4);return a.onerror=a.onload=c,n.appendChild(a),e},i.m=t,i.c=n,i.d=function(t,e,n){i.o(t,e)||Object.defineProperty(t,e,{enumerable:!0,get:n})},i.r=function(t){"undefined"!==typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},i.t=function(t,e){if(1&e&&(t=i(t)),8&e)return t;if(4&e&&"object"===typeof t&&t&&t.__esModule)return t;var n=Object.create(null);if(i.r(n),Object.defineProperty(n,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var r in t)i.d(n,r,function(e){return t[e]}.bind(null,r));return n},i.n=function(t){var e=t&&t.__esModule?function(){return t["default"]}:function(){return t};return i.d(e,"a",e),e},i.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},i.p="/",i.oe=function(t){throw console.error(t),t};var u=window.ansFrontendRelayWebpackJsonpFunction=window.ansFrontendRelayWebpackJsonpFunction||[],a=u.push.bind(u);u.push=e,u=u.slice();for(var c=0;c<u.length;c++)e(u[c]);var s=a;i(i.s=0)}({0:function(t,e,n){t.exports=n("oqNQ")},"8oxB":function(t,e){var n,r,o=t.exports={};function i(){throw new Error("setTimeout has not been defined")}function u(){throw new Error("clearTimeout has not been defined")}function a(t){if(n===setTimeout)return setTimeout(t,0);if((n===i||!n)&&setTimeout)return n=setTimeout,setTimeout(t,0);try{return n(t,0)}catch(e){try{return n.call(null,t,0)}catch(e){return n.call(this,t,0)}}}!function(){try{n="function"===typeof setTimeout?setTimeout:i}catch(t){n=i}try{r="function"===typeof clearTimeout?clearTimeout:u}catch(t){r=u}}();var c,s=[],f=!1,l=-1;function d(){f&&c&&(f=!1,c.length?s=c.concat(s):l=-1,s.length&&h())}function h(){if(!f){var t=a(d);f=!0;for(var e=s.length;e;){for(c=s,s=[];++l<e;)c&&c[l].run();l=-1,e=s.length}c=null,f=!1,function(t){if(r===clearTimeout)return clearTimeout(t);if((r===u||!r)&&clearTimeout)return r=clearTimeout,clearTimeout(t);try{r(t)}catch(e){try{return r.call(null,t)}catch(e){return r.call(this,t)}}}(t)}}function p(t,e){this.fun=t,this.array=e}function v(){}o.nextTick=function(t){var e=new Array(arguments.length-1);if(arguments.length>1)for(var n=1;n<arguments.length;n++)e[n-1]=arguments[n];s.push(new p(t,e)),1!==s.length||f||a(h)},p.prototype.run=function(){this.fun.apply(null,this.array)},o.title="browser",o.browser=!0,o.env={},o.argv=[],o.version="",o.versions={},o.on=v,o.addListener=v,o.once=v,o.off=v,o.removeListener=v,o.removeAllListeners=v,o.emit=v,o.prependListener=v,o.prependOnceListener=v,o.listeners=function(t){return[]},o.binding=function(t){throw new Error("process.binding is not supported")},o.cwd=function(){return"/"},o.chdir=function(t){throw new Error("process.chdir is not supported")},o.umask=function(){return 0}},E2g8:function(t,e,n){(function(e,n){var r;r=function(){"use strict";function t(t){return"function"===typeof t}var r=Array.isArray?Array.isArray:function(t){return"[object Array]"===Object.prototype.toString.call(t)},o=0,i=void 0,u=void 0,a=function(t,e){p[o]=t,p[o+1]=e,2===(o+=2)&&(u?u(v):y())},c="undefined"!==typeof window?window:undefined,s=c||{},f=s.MutationObserver||s.WebKitMutationObserver,l="undefined"===typeof self&&"undefined"!==typeof e&&"[object process]"==={}.toString.call(e),d="undefined"!==typeof Uint8ClampedArray&&"undefined"!==typeof importScripts&&"undefined"!==typeof MessageChannel;function h(){var t=setTimeout;return function(){return t(v,1)}}var p=new Array(1e3);function v(){for(var t=0;t<o;t+=2)(0,p[t])(p[t+1]),p[t]=undefined,p[t+1]=undefined;o=0}var y=void 0;function w(t,e){var n=this,r=new this.constructor(b);r[g]===undefined&&T(r);var o=n._state;if(o){var i=arguments[o-1];a((function(){return A(o,r,i,n._result)}))}else L(n,r,t,e);return r}function m(t){if(t&&"object"===typeof t&&t.constructor===this)return t;var e=new this(b);return x(e,t),e}y=l?function(){return e.nextTick(v)}:f?function(){var t=0,e=new f(v),n=document.createTextNode("");return e.observe(n,{characterData:!0}),function(){n.data=t=++t%2}}():d?function(){var t=new MessageChannel;return t.port1.onmessage=v,function(){return t.port2.postMessage(0)}}():c===undefined?function(){try{var t=Function("return this")().require("vertx");return"undefined"!==typeof(i=t.runOnLoop||t.runOnContext)?function(){i(v)}:h()}catch(e){return h()}}():h();var g=Math.random().toString(36).substring(2);function b(){}function _(e,n,r){n.constructor===e.constructor&&r===w&&n.constructor.resolve===m?function(t,e){1===e._state?P(t,e._result):2===e._state?O(t,e._result):L(e,undefined,(function(e){return x(t,e)}),(function(e){return O(t,e)}))}(e,n):r===undefined?P(e,n):t(r)?function(t,e,n){a((function(t){var r=!1,o=function(t,e,n,r){try{t.call(e,n,r)}catch(o){return o}}(n,e,(function(n){r||(r=!0,e!==n?x(t,n):P(t,n))}),(function(e){r||(r=!0,O(t,e))}),t._label);!r&&o&&(r=!0,O(t,o))}),t)}(e,n,r):P(e,n)}function x(t,e){if(t===e)O(t,new TypeError("You cannot resolve a promise with itself"));else if(function(t){var e=typeof t;return null!==t&&("object"===e||"function"===e)}(e)){var n=void 0;try{n=e.then}catch(r){return void O(t,r)}_(t,e,n)}else P(t,e)}function j(t){t._onerror&&t._onerror(t._result),E(t)}function P(t,e){void 0===t._state&&(t._result=e,t._state=1,0!==t._subscribers.length&&a(E,t))}function O(t,e){void 0===t._state&&(t._state=2,t._result=e,a(j,t))}function L(t,e,n,r){var o=t._subscribers,i=o.length;t._onerror=null,o[i]=e,o[i+1]=n,o[i+2]=r,0===i&&t._state&&a(E,t)}function E(t){var e=t._subscribers,n=t._state;if(0!==e.length){for(var r=void 0,o=void 0,i=t._result,u=0;u<e.length;u+=3)r=e[u],o=e[u+n],r?A(n,r,o,i):o(i);t._subscribers.length=0}}function A(e,n,r,o){var i=t(r),u=void 0,a=void 0,c=!0;if(i){try{u=r(o)}catch(s){c=!1,a=s}if(n===u)return void O(n,new TypeError("A promises callback cannot return that same promise."))}else u=o;void 0!==n._state||(i&&c?x(n,u):!1===c?O(n,a):1===e?P(n,u):2===e&&O(n,u))}var S=0;function T(t){t[g]=S++,t._state=undefined,t._result=undefined,t._subscribers=[]}var F=function(){function t(t,e){this._instanceConstructor=t,this.promise=new t(b),this.promise[g]||T(this.promise),r(e)?(this.length=e.length,this._remaining=e.length,this._result=new Array(this.length),0===this.length?P(this.promise,this._result):(this.length=this.length||0,this._enumerate(e),0===this._remaining&&P(this.promise,this._result))):O(this.promise,new Error("Array Methods must be provided an Array"))}return t.prototype._enumerate=function(t){for(var e=0;void 0===this._state&&e<t.length;e++)this._eachEntry(t[e],e)},t.prototype._eachEntry=function(t,e){var n=this._instanceConstructor,r=n.resolve;if(r===m){var o=void 0,i=void 0,u=!1;try{o=t.then}catch(c){u=!0,i=c}if(o===w&&void 0!==t._state)this._settledAt(t._state,e,t._result);else if("function"!==typeof o)this._remaining--,this._result[e]=t;else if(n===C){var a=new n(b);u?O(a,i):_(a,t,o),this._willSettleAt(a,e)}else this._willSettleAt(new n((function(e){return e(t)})),e)}else this._willSettleAt(r(t),e)},t.prototype._settledAt=function(t,e,n){var r=this.promise;void 0===r._state&&(this._remaining--,2===t?O(r,n):this._result[e]=n),0===this._remaining&&P(r,this._result)},t.prototype._willSettleAt=function(t,e){var n=this;L(t,undefined,(function(t){return n._settledAt(1,e,t)}),(function(t){return n._settledAt(2,e,t)}))},t}(),C=function(){function e(t){this[g]=S++,this._result=this._state=undefined,this._subscribers=[],b!==t&&("function"!==typeof t&&function(){throw new TypeError("You must pass a resolver function as the first argument to the promise constructor")}(),this instanceof e?function(t,e){try{e((function(e){x(t,e)}),(function(e){O(t,e)}))}catch(n){O(t,n)}}(this,t):function(){throw new TypeError("Failed to construct 'Promise': Please use the 'new' operator, this object constructor cannot be called as a function.")}())}return e.prototype["catch"]=function(t){return this.then(null,t)},e.prototype["finally"]=function(e){var n=this.constructor;return t(e)?this.then((function(t){return n.resolve(e()).then((function(){return t}))}),(function(t){return n.resolve(e()).then((function(){throw t}))})):this.then(e,e)},e}();return C.prototype.then=w,C.all=function(t){return new F(this,t).promise},C.race=function(t){var e=this;return r(t)?new e((function(n,r){for(var o=t.length,i=0;i<o;i++)e.resolve(t[i]).then(n,r)})):new e((function(t,e){return e(new TypeError("You must pass an array to race."))}))},C.resolve=m,C.reject=function(t){var e=new this(b);return O(e,t),e},C._setScheduler=function(t){u=t},C._setAsap=function(t){a=t},C._asap=a,C.polyfill=function(){var t=void 0;if("undefined"!==typeof n)t=n;else if("undefined"!==typeof self)t=self;else try{t=Function("return this")()}catch(o){throw new Error("polyfill failed because global object is unavailable in this environment")}var e=t.Promise;if(e){var r=null;try{r=Object.prototype.toString.call(e.resolve())}catch(o){}if("[object Promise]"===r&&!e.cast)return}t.Promise=C},C.Promise=C,C},t.exports=r()}).call(this,n("8oxB"),n("yLpj"))},MMrh:function(t,e,n){var r=function(){return this||"object"===typeof self&&self}()||Function("return this")(),o=r.regeneratorRuntime&&Object.getOwnPropertyNames(r).indexOf("regeneratorRuntime")>=0,i=o&&r.regeneratorRuntime;if(r.regeneratorRuntime=undefined,t.exports=n("nXbr"),o)r.regeneratorRuntime=i;else try{delete r.regeneratorRuntime}catch(u){r.regeneratorRuntime=undefined}},VLrD:function(t,e,n){"use strict";t.exports=n("E2g8").polyfill()},jQsN:function(t,e,n){t.exports=n("MMrh")},nXbr:function(t,e){!function(e){"use strict";var n=Object.prototype,r=n.hasOwnProperty,o="function"===typeof Symbol?Symbol:{},i=o.iterator||"@@iterator",u=o.asyncIterator||"@@asyncIterator",a=o.toStringTag||"@@toStringTag",c="object"===typeof t,s=e.regeneratorRuntime;if(s)c&&(t.exports=s);else{(s=e.regeneratorRuntime=c?t.exports:{}).wrap=v;var f={},l={};l[i]=function(){return this};var d=Object.getPrototypeOf,h=d&&d(d(L([])));h&&h!==n&&r.call(h,i)&&(l=h);var p=g.prototype=w.prototype=Object.create(l);m.prototype=p.constructor=g,g.constructor=m,g[a]=m.displayName="GeneratorFunction",s.isGeneratorFunction=function(t){var e="function"===typeof t&&t.constructor;return!!e&&(e===m||"GeneratorFunction"===(e.displayName||e.name))},s.mark=function(t){return Object.setPrototypeOf?Object.setPrototypeOf(t,g):(t.__proto__=g,a in t||(t[a]="GeneratorFunction")),t.prototype=Object.create(p),t},s.awrap=function(t){return{__await:t}},b(_.prototype),_.prototype[u]=function(){return this},s.AsyncIterator=_,s.async=function(t,e,n,r){var o=new _(v(t,e,n,r));return s.isGeneratorFunction(e)?o:o.next().then((function(t){return t.done?t.value:o.next()}))},b(p),p[a]="Generator",p[i]=function(){return this},p.toString=function(){return"[object Generator]"},s.keys=function(t){var e=[];for(var n in t)e.push(n);return e.reverse(),function r(){for(;e.length;){var n=e.pop();if(n in t)return r.value=n,r.done=!1,r}return r.done=!0,r}},s.values=L,O.prototype={constructor:O,reset:function(t){if(this.prev=0,this.next=0,this.sent=this._sent=void 0,this.done=!1,this.delegate=null,this.method="next",this.arg=void 0,this.tryEntries.forEach(P),!t)for(var e in this)"t"===e.charAt(0)&&r.call(this,e)&&!isNaN(+e.slice(1))&&(this[e]=void 0)},stop:function(){this.done=!0;var t=this.tryEntries[0].completion;if("throw"===t.type)throw t.arg;return this.rval},dispatchException:function(t){if(this.done)throw t;var e=this;function n(n,r){return u.type="throw",u.arg=t,e.next=n,r&&(e.method="next",e.arg=void 0),!!r}for(var o=this.tryEntries.length-1;o>=0;--o){var i=this.tryEntries[o],u=i.completion;if("root"===i.tryLoc)return n("end");if(i.tryLoc<=this.prev){var a=r.call(i,"catchLoc"),c=r.call(i,"finallyLoc");if(a&&c){if(this.prev<i.catchLoc)return n(i.catchLoc,!0);if(this.prev<i.finallyLoc)return n(i.finallyLoc)}else if(a){if(this.prev<i.catchLoc)return n(i.catchLoc,!0)}else{if(!c)throw new Error("try statement without catch or finally");if(this.prev<i.finallyLoc)return n(i.finallyLoc)}}}},abrupt:function(t,e){for(var n=this.tryEntries.length-1;n>=0;--n){var o=this.tryEntries[n];if(o.tryLoc<=this.prev&&r.call(o,"finallyLoc")&&this.prev<o.finallyLoc){var i=o;break}}i&&("break"===t||"continue"===t)&&i.tryLoc<=e&&e<=i.finallyLoc&&(i=null);var u=i?i.completion:{};return u.type=t,u.arg=e,i?(this.method="next",this.next=i.finallyLoc,f):this.complete(u)},complete:function(t,e){if("throw"===t.type)throw t.arg;return"break"===t.type||"continue"===t.type?this.next=t.arg:"return"===t.type?(this.rval=this.arg=t.arg,this.method="return",this.next="end"):"normal"===t.type&&e&&(this.next=e),f},finish:function(t){for(var e=this.tryEntries.length-1;e>=0;--e){var n=this.tryEntries[e];if(n.finallyLoc===t)return this.complete(n.completion,n.afterLoc),P(n),f}},"catch":function(t){for(var e=this.tryEntries.length-1;e>=0;--e){var n=this.tryEntries[e];if(n.tryLoc===t){var r=n.completion;if("throw"===r.type){var o=r.arg;P(n)}return o}}throw new Error("illegal catch attempt")},delegateYield:function(t,e,n){return this.delegate={iterator:L(t),resultName:e,nextLoc:n},"next"===this.method&&(this.arg=void 0),f}}}function v(t,e,n,r){var o=e&&e.prototype instanceof w?e:w,i=Object.create(o.prototype),u=new O(r||[]);return i._invoke=function(t,e,n){var r="suspendedStart";return function(o,i){if("executing"===r)throw new Error("Generator is already running");if("completed"===r){if("throw"===o)throw i;return E()}for(n.method=o,n.arg=i;;){var u=n.delegate;if(u){var a=x(u,n);if(a){if(a===f)continue;return a}}if("next"===n.method)n.sent=n._sent=n.arg;else if("throw"===n.method){if("suspendedStart"===r)throw r="completed",n.arg;n.dispatchException(n.arg)}else"return"===n.method&&n.abrupt("return",n.arg);r="executing";var c=y(t,e,n);if("normal"===c.type){if(r=n.done?"completed":"suspendedYield",c.arg===f)continue;return{value:c.arg,done:n.done}}"throw"===c.type&&(r="completed",n.method="throw",n.arg=c.arg)}}}(t,n,u),i}function y(t,e,n){try{return{type:"normal",arg:t.call(e,n)}}catch(r){return{type:"throw",arg:r}}}function w(){}function m(){}function g(){}function b(t){["next","throw","return"].forEach((function(e){t[e]=function(t){return this._invoke(e,t)}}))}function _(t){var e;this._invoke=function(n,o){function i(){return new Promise((function(e,i){!function u(e,n,o,i){var a=y(t[e],t,n);if("throw"!==a.type){var c=a.arg,s=c.value;return s&&"object"===typeof s&&r.call(s,"__await")?Promise.resolve(s.__await).then((function(t){u("next",t,o,i)}),(function(t){u("throw",t,o,i)})):Promise.resolve(s).then((function(t){c.value=t,o(c)}),(function(t){return u("throw",t,o,i)}))}i(a.arg)}(n,o,e,i)}))}return e=e?e.then(i,i):i()}}function x(t,e){var n=t.iterator[e.method];if(void 0===n){if(e.delegate=null,"throw"===e.method){if(t.iterator["return"]&&(e.method="return",e.arg=void 0,x(t,e),"throw"===e.method))return f;e.method="throw",e.arg=new TypeError("The iterator does not provide a 'throw' method")}return f}var r=y(n,t.iterator,e.arg);if("throw"===r.type)return e.method="throw",e.arg=r.arg,e.delegate=null,f;var o=r.arg;return o?o.done?(e[t.resultName]=o.value,e.next=t.nextLoc,"return"!==e.method&&(e.method="next",e.arg=void 0),e.delegate=null,f):o:(e.method="throw",e.arg=new TypeError("iterator result is not an object"),e.delegate=null,f)}function j(t){var e={tryLoc:t[0]};1 in t&&(e.catchLoc=t[1]),2 in t&&(e.finallyLoc=t[2],e.afterLoc=t[3]),this.tryEntries.push(e)}function P(t){var e=t.completion||{};e.type="normal",delete e.arg,t.completion=e}function O(t){this.tryEntries=[{tryLoc:"root"}],t.forEach(j,this),this.reset(!0)}function L(t){if(t){var e=t[i];if(e)return e.call(t);if("function"===typeof t.next)return t;if(!isNaN(t.length)){var n=-1,o=function e(){for(;++n<t.length;)if(r.call(t,n))return e.value=t[n],e.done=!1,e;return e.value=void 0,e.done=!0,e};return o.next=o}}return{next:E}}function E(){return{value:void 0,done:!0}}}(function(){return this||"object"===typeof self&&self}()||Function("return this")())},nqWu:function(t,e,n){"use strict";n.d(e,"b",(function(){return o}));var r={},o=function(){return Object.assign({},r)};e.a=function(t){var e,n,o=arguments.length>1&&arguments[1]!==undefined?arguments[1]:"",i=window,u=Date.now();if(t=o+t,null!==(e=i.ansFrontendGlobals)&&void 0!==e&&null!==(n=e.earlySettings)&&void 0!==n&&n.react_console_log_perf_info){var a,c=null!==(a=i.performance)&&void 0!==a&&a.now?i.performance.now():u;console.log("".concat(t,": ").concat(c))}r[t]||(r[t]=u)}},oqNQ:function(t,e,n){"use strict";n.r(e);var r=n("jQsN"),o=n.n(r),i=n("tcRq"),u=n.n(i),a=(n("VLrD"),n("nqWu"));Object(a.a)("moduleLoaded-entry");var c=function(t){return!("undefined"!==typeof fetch&&"undefined"!==typeof Promise&&Object.values&&Object.entries)?function(e){return n.e("polyfills").then(n.bind(null,"ZjFC")).then((function(){return t(e)}))}:t},s=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"A+VG")).then((function(e){return t(e)}))})),f=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"SKAY")).then((function(e){return t(e)}))})),l=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"wP3S")).then((function(e){return t(e)}))})),d=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"Gnru")).then((function(e){return t(e)}))})),h=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"0xW3")).then((function(e){return t(e)}))})),p=c((function(t){return Promise.all([n.e("vendor"),n.e("common")]).then(n.bind(null,"p11P")).then((function(e){return t(e)}))})),v=c((function(t){return Promise.all([n.e("vendor"),n.e("ssr")]).then(n.bind(null,"4EOz")).then((function(e){return t(e)}))}));window.runApp=function(){Object(a.a)("windowFunctionCalled-runApp"),s((function(t){t.runApp()}))},window.inlineReact=function(t,e,n,r){Object(a.a)("windowFunctionCalled-inlineReact"),w(t,e,n,r)},window.shimProxy=window.shimProxy||{webnodeSubscribeEventsQueue:[]};var y=!1,w=function(t,e,n,r){var o=function(){y||(y=!0,s((function(o){Object(a.a)("StartAppInlineReactCalled","loadable"),o.inlineReact(t,e,n,r)})))};window.shimProxy.webnode?window.shimProxy.webnode.subscribe("REACT_LOADABLE_LOADED",o):window.shimProxy.webnodeSubscribeEventsQueue.push(["REACT_LOADABLE_LOADED",o])};window.renderPrefetchedPage=function(t,e,n){Object(a.a)("windowFunctionCalled-renderPrefetchedPage"),s((function(r){r.renderPrefetchedPage(t,e,n)}))},window.renderPrefetchedPageModalDeprecated=function(t){s((function(e){e.renderPrefetchedPageModalDeprecated(t)}))},window.reportPageSpeedData=function(t){Object(a.a)("windowFunctionCalled-reportPageSpeedData"),l((function(e){return e.reportPageData(t)}))},window.setTimingData=function(t){Object(a.a)("windowFunctionCalled-setTimingData"),l((function(e){return e.setTimingData(t)}))},window.setGlobalMetadata=function(t){Object(a.a)("windowFunctionCalled-setGlobalMetadata"),d((function(e){return e.setGlobalMetadata(t)}))},window.updateGlobalMetadata=function(t){Object(a.a)("windowFunctionCalled-updateGlobalMetadata"),d((function(e){return e.updateGlobalMetadata(t)}))},window.setServerPerfCheckpointData=function(t){Object(a.a)("windowFunctionCalled-setServerPerfCheckpointData"),l((function(e){return e.setServerPerfCheckpointData(t)}))},window.setWebnodeLoadable=function(t){Object(a.a)("windowFunctionCalled-setWebnodeLoadable"),h((function(e){return e.setWebnodeLoadable(t)}))},window.fetchAndSetWebnodeLoadable=function(){Object(a.a)("windowFunctionCalled-fetchAndSetWebnodeLoadable"),h((function(t){return t.fetchAndSetWebnodeLoadable()}))},window.installSettings=function(){Object(a.a)("windowFunctionCalled-installSettings"),f((function(t){return t.installSettings()}))},window.loadServerRelayRecords=function(t){Object(a.a)("windowFunctionCalled-loadServerRelayRecords"),p((function(e){return e.loadServerRelayRecords(t)}))},window.renderApp=function(){var t=u()(o.a.mark((function e(t,n){var r;return o.a.wrap((function(e){for(;;)switch(e.prev=e.next){case 0:return n("windowFunctionCalled-renderApp"),e.next=3,f((function(t){t.installSettings()}));case 3:return e.next=5,p((function(t){return t["default"]}));case 5:return r=e.sent,e.abrupt("return",v((function(e){return e.renderApp(r,t,n)})));case 7:case"end":return e.stop()}}),e)})));return function(e,n){return t.apply(this,arguments)}}()},tcRq:function(t,e){function n(t,e,n,r,o,i,u){try{var a=t[i](u),c=a.value}catch(s){return void n(s)}a.done?e(c):Promise.resolve(c).then(r,o)}t.exports=function(t){return function(){var e=this,r=arguments;return new Promise((function(o,i){var u=t.apply(e,r);function a(t){n(u,o,i,a,c,"next",t)}function c(t){n(u,o,i,a,c,"throw",t)}a(undefined)}))}}},yLpj:function(t,e){var n;n=function(){return this}();try{n=n||new Function("return this")()}catch(r){"object"===typeof window&&(n=window)}t.exports=n}});</script><script type='text/javascript' src='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ac99ceb1b9c10014.webpack' async='1' defer='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-15b26220d3ee4250.webpack' async='1' defer='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-27-847dd7e3d7f6b8cc.webpack' async='1' defer='1' onerror='addAssetErr(this.src)'></script><script type="text/javascript">window.runApp();</script><script type="text/javascript">var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),t=new XMLHttpRequest;t.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),t.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),t.setRequestHeader("Accept","*/*"),t.send(e.replace(/%20/g,"+"))}},0)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};</script>
   </head>
   <body class='q-platform--desktop' style='margin: 0;padding: 0;'>
      <div id='root'></div>
      <noscript>Please enable Javascript and refresh the page to continue</noscript>
      <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};
         window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
         window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
         window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
         window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
         window.ansFrontendGlobals.data.inlineQueryResults.results["2f873aed85d7270c58b44eeb7ee01e5cfc8bd4cc6ce6018b93840a89ffc1c155"] = "{\"data\":{\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"tribesItemInSiteHeader\":true,\"tribeNavBadgeCount\":0,\"showGoToFeedGrowl\":false,\"showGoToFeedGrowlBadge\":false,\"followingTabBadgeCount\":0,\"writeNavBadgeCount\":0,\"profileNavBadgeCount\":0,\"notificationNavBadgeCount\":0,\"user\":null,\"uid\":null,\"nid\":0,\"silosBadgeCount\":\"{}\",\"memberNetworks\":[],\"followingFeedEnabled\":true,\"isAdminMode\":false,\"followingFeedEnabledOnNetwork\":true,\"canSeeAds\":true,\"cookieBanner\":{\"id\":\"Q29va2llQmFubmVyQDA6cHFMeFlFaTMxZ05TQjFBSE93RTZfQT09\",\"__typename\":\"CookieBanner\",\"browserId\":\"pqLxYEi31gNSB1AHOwE6_A==\",\"bannerType\":1},\"isUniversalLoggedIn\":false,\"isGdprApplicable\":true,\"userNameUseJapaneseEditor\":false,\"signupId\":\"pqLxYEi31gNSB1AHOwE6_A==_1617389289431867\"},\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"loginShouldShowLogoutAll\":false,\"facebookConnectInfo\":{\"nonce\":null,\"id\":\"RmFjZWJvb2tDb25uZWN0SW5mbzpwcUx4WUVpMzFnTlNCMUFIT3dFNl9BPT06ZW5fVVM6RmFsc2U6Tm9uZQ==\"}},\"broadcastId\":\"main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC\",\"tchannelData\":{\"minSeq\":\"0\",\"channel\":\"main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC\",\"channelHash\":\"13498512337374325347\",\"boxName\":\"chan52-8888\",\"baseHost\":\"quora.com\",\"targetUrl\":\"\",\"enableWebsocket\":true},\"broadcastData\":{\"categoryToDepkeys\":{\"Viewer:isUniversalLoggedIn:Vmlld2VyQDA6MA==\":[\"LIUS:96900f599c353d059b4296cace11a038\",\"LIUB:cb0dbae39579eed46971106aefc92745\"]},\"depkeyToVersion\":{\"LIUB:cb0dbae39579eed46971106aefc92745\":0,\"LIUS:96900f599c353d059b4296cace11a038\":0}}}";
         window.ansFrontendGlobals.data.inlineQueryResults.next["2f873aed85d7270c58b44eeb7ee01e5cfc8bd4cc6ce6018b93840a89ffc1c155"] && window.ansFrontendGlobals.data.inlineQueryResults.next["2f873aed85d7270c58b44eeb7ee01e5cfc8bd4cc6ce6018b93840a89ffc1c155"]();
      </script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};
         window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
         window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
         window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
         window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
         window.ansFrontendGlobals.data.inlineQueryResults.results["95f35eb8a38fee5ed862eedc4d9c347516661a2d7bd1f5e70bd1767f9af15d4c"] = "{\"data\":{\"viewer\":{\"user\":null,\"tribeWallInfo\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"network\":{\"id\":\"TmV0d29yazow\",\"__typename\":\"Network\"},\"activationWall\":null,\"actionBasedWall\":null,\"followTribeWallDeck\":null,\"browserNotifWallDeck\":null,\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"facebookPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"googlePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"keyweePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"twitterPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaPixel\":{\"awinAwc\":null,\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaViewer\":{\"uid\":null,\"locationCountryCode\":\"IE\",\"id\":\"Vmlld2VyQDA6MA==\"},\"quoraPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaViewer\":{\"primaryEmail\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"tikTokPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"liveRampPixel\":{\"liverampHash\":null,\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"}},\"broadcastId\":\"main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC\",\"tchannelData\":{\"minSeq\":\"0\",\"channel\":\"main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC\",\"channelHash\":\"13498512337374325347\",\"boxName\":\"chan52-8888\",\"baseHost\":\"quora.com\",\"targetUrl\":\"\",\"enableWebsocket\":true},\"broadcastData\":{\"categoryToDepkeys\":{\"Viewer:isUniversalLoggedIn:Vmlld2VyQDA6MA==\":[\"LIUS:96900f599c353d059b4296cace11a038\",\"LIUB:cb0dbae39579eed46971106aefc92745\"]},\"depkeyToVersion\":{\"LIUB:cb0dbae39579eed46971106aefc92745\":0,\"LIUS:96900f599c353d059b4296cace11a038\":0}}}";
         window.ansFrontendGlobals.data.inlineQueryResults.next["95f35eb8a38fee5ed862eedc4d9c347516661a2d7bd1f5e70bd1767f9af15d4c"] && window.ansFrontendGlobals.data.inlineQueryResults.next["95f35eb8a38fee5ed862eedc4d9c347516661a2d7bd1f5e70bd1767f9af15d4c"]();
      </script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "q", "controller": "question", "pageType": "question", "pageOid": 994236, "getPageTypeOfRefererUrl": null, "getRefererUrl": "", "getRefererUrlTarget": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "0a952343942873c97a141835dd3c2fd0dd7d4244", "isCanaryRevision": false, "debugToolsEnabled": false, "graphqlClientRequestLogging": true, "persistedQueriesEnabled": true, "postkey": "e44d968b1d96e9040a8dd991a67080d6", "buildNumber": 0, "broadcastId": "main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC", "broadcastDisabled": false, "tchannelData": {"minSeq": "0", "channel": "main-w-chan52-8888-react_vpopiagoqpmcidij-fhXC", "channelHash": "13498512337374325347", "boxName": "chan52-8888", "baseHost": "quora.com", "targetUrl": "", "enableWebsocket": true}, "viewerUid": null, "isQuoraEmployee": false, "shouldReportE2E": false, "shouldReportReactLoadableE2E": false, "cdn": "fastly", "request_id": "db766a570bf9436fa501c1051b4cb627", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "stacked_space_suggestions": null, "send_nullspace_content_notifs_to_followers_of_author": null, "simple_app_download_wall": null, "simple_app_download_wall_2": null, "react_credential_modals": null, "remove_story_metadata": null, "prominent_short_stories_v2": null, "space_creation_homefeed_compressed": null, "new_image_layout": null, "space_creation_feed_desktop": null, "share_from_android_2": null, "share_into_android": null, "space_discardable_modal_ios": null, "write_page_fetch": null, "notif_email_unsub_page_react": null, "merge_question_modal_react": null, "push_notif_lightweight_survey": null, "suggested_tribe_email_notif_holdout": null, "show_upvote_tooltip": null, "next_notif_button_mweb": null, "nux_topic_step_reduce_friction_v2": null, "a2a_space_request_v2": null, "reduce_questions_in_question_bundle_home_feed": null, "styled_pre_expand_stories": null, "react_notifs_dropdown_menu": null, "tribe_suggestions_reasons_tags": null, "feed_story_comment_preview": null, "new_tribe_answer_composer": null, "unified_composer": null, "tribe_page_redesign_uid": null, "tribe_page_redesign_browser_id": "show_redesign", "new_comment_composer_layout": null, "combine_action_btn_in_composers": null, "unified_composer_header": null, "share_to_post": null, "new_tribe_question_action_bar": null}, "features": {"UseExtraAnimationInInterface": true, "TribesNameCharacterLimit": 50, "TribesDescriptionCharacterLimit": 80, "PaidSubscriptionProgramsEnabled": false, "StyleLineHeightFeature": 1, "StyleFontFamilyFeature": 1, "DefaultContentBidiDirectionIsRTL": false, "AllowColorModesInInterface": false, "UseAllCapsInInterface": true, "NuxFollowTopicsLowerRequirements": true, "SmartQuotesEnabled": true, "DisabledEditorCommands": [], "TribeEarningsProgramFeature": true}, "gates": {"ads_show_message_banner": {"message": null, "learn_more_link": null}, "enable_ad_placement_targeting": false, "lead_gen_logged_out": true, "enable_react_multiple_ad_account_override": false, "enable_existing_payment_methods_flow_override": false, "space_revenue_share_supported_country_codes": ["AU", "BE", "CA", "CH", "DK", "FI", "FR", "DE", "GB", "HK", "IN", "ID", "IE", "IL", "IT", "MT", "MX", "NL", "NO", "NZ", "PT", "ES", "SE", "SG", "US"], "enable_business_services": false, "enable_business_services_user": true, "business_services_billing": false, "enable_null_space_writer_bundle_program": false, "paid_only_content_ids": [], "enable_feed_paid_slot": false, "react-account-switch-modal": false, "connect_stripe_employee_allowlist": [], "full_react_desktop_site_header_notifs_nav_item": false, "a2a_space_request": null, "q1_notif_ui": false, "force_show_app_digest": false, "force_inject_suggested_spaces": [], "activation_tribes_discover_link": false, "allow_invalid_feed_reason_following_feed": false, "unsubscribe_digest_email_user_survey": false, "notif_survey_prompt": false, "fb_limited_login_ios": false, "fb_limited_login_server_changes": true, "use_merge_questions_react": false, "feed_story_comment_preview": null, "annotate_with_translation_template_info": false, "show_aggressive_prompt_on_question_page_force": null, "react_i18n_translation_lookup_console_log": false, "react_i18n_translation_rendered_console_log": false, "react_i18n_translation_enforce_pseudo_l10n": false, "react_i18n_translation_internal_plaintext_log_error": false, "meetup_week_registration_link": "https://www.quora.com/q/quora/Quora-World-Meetup-Week-2020", "mobile_react_edit_topic_page": false, "new_name_policy": false, "enable_topic_gnome_operations": false, "partner_indicator": false, "repeat_offender": true, "use_react_login_signup": true, "coronavirus_topics": [], "use_dev_mode_captcha": false, "voter_misinfo_topics": [], "question_clusters_variant": null, "related_answers_filter": false, "can_edit_notable_writers": false, "unread_messages_filter": false, "google_contact_import": false, "tribes_super_admin": false, "create_tribe_flow": false, "search_in_tribes": false, "search_share_result_in_tribes": false, "tribe_sharing_mode_toggle": false, "dead_tribe_application_form_url": "https://docs.google.com/forms/d/1ckgoaLlluh2K9KP4SDnPjQW92JgktyY88-OliQZJtBs", "remove_featured_comments_split_react": true, "disable_blocking_app_modal_mweb": false, "react_space_page_universal_composer": null, "comments_modal_react": false, "coronavirus_who_url": "https://www.who.int/emergencies/diseases/novel-coronavirus-2019", "coronavirus_cdc_url": "https://www.cdc.gov/", "tribes_with_higher_content_queue_max_dequeue_rate": [1587006, 59], "create_tribe_announcement": false, "create_tribe_announcement_blog_post_url": "https://www.quora.com/q/spaceupdates/Introducing-ads-in-Spaces-and-other-news", "react_tribe_settings_modals": false, "disallow_posts_with_embeds_if_shares_disabled_in_space": false, "tribes_a2a": true, "enable_subscriptions_and_bundles": false, "tribe_spam_ui": true, "user_profile_email_discovery_setting": true, "tribes_a2a_debug": false, "new_producer_invite_ui": true, "share_to_post": false, "new_tribe_answer_composer": true, "programming_contest_open_registration": true, "programming_contest_show_login_info": true, "programming_contest_home_feed_announcement": false, "unified_composer": true, "tribe_page_redesign": true, "default_share_to_your_followers": true, "tribe_page_google_one_tap": true, "queue_tab_reorder_item": true, "show_block_button_in_request_to_contribute": true, "show_tribe_subdomain_url_on_ui": false, "tribe_invite_csv_upload": true, "sort_by_metric_in_tribe_people_tab": true, "tribes_page_sort_by_role": true, "bypass_space_name_restrictions": false, "new_tribe_submission_suggestion_action_bar": false, "new_comment_composer_layout": true, "combine_action_btn_in_composers": true, "show_undo_button_for_passed_submissions": true, "show_user_join_date": true, "unified_composer_header": true, "render_give_pass_reason_react": true, "use_react_stats_page": false, "redirect_your_content_to_search": false, "deprecate_topic_leaderbooard": true, "convert_hyperlink_embed_to_linkified_text": true, "higher_tribe_invite_rate_limit": true, "show_tribe_admin_report_reasons_and_comments": true, "tribe_preferred_feed_sort": false, "combined_content_rate_limit": true, "tribe_submissions_off_by_default": false, "resolved_question_submission_ui_change": false, "resolved_question_suggestion_ui_change": false, "space_level_topics_removed": false, "new_tribe_question_action_bar": false, "dark_mode_debug_button": false, "ios_pull_to_refresh_js": false, "space_subdomain": false, "space_subdomain_login": true, "google_one_tap_domain": null, "google_contact_import_iframe": true, "disable_app_rating_prompt": false, "write_page_fetch": true, "share_from_android": null, "share_into_android": true, "space_discardable_modal_ios": false, "inline_comment_composer": false, "record_prefetched_page_in_react": true, "react_ask_button_pressed": true, "show_react_ama_self_serve_start_session_modal": true, "show_react_ama_self_serve_edit_session_modal": true, "android_in_app_update": false, "use_react_appeal_modal": false, "annotate_with_ids": false, "spaces_feed_navigation": false, "create_space_desktop": false, "test_setting": true, "use_log_subdomain_for_log_sender_react": false, "use_log_subdomain_for_log_sender": true, "client_side_batched_logging_interval": 2000, "verbose_client_logging_categories": [], "react_console_log_perf_info": false, "asset_source_override": null, "server_side_spoof_native_app_user_agent": false, "react_include_client_log_trail": true, "hide_react_logo": false, "user_perceived_mutation_perf_sample_rate": 0.1, "show_react_live_update_banner": true, "log_web_vitals": true, "paged_list_perf": true, "use_react_credentials": false, "contribute_request_show_passed_submission_num": true, "nux_checklist_cta": true, "space_subdomain_url_debug": true, "tribe_submission_queue_undo": true, "disable_prefetching_for_related_questions": false, "disable_prefetching_for_user_link_wrapper": true, "enable_space_post_drafts_autosave_on_native_platforms": true, "use_react_third_party_pixels": true, "a2a_user_perceived_debug_sample_rate": 0.1, "use_react_ama_self_serve_stop_modal": true}, "googleClientId": "917071888555.apps.googleusercontent.com", "googleCookiePolicy": "https://quora.com", "isLoggedIn": false, "isCrawler": false, "webBaseUrl": "http://www.quora.com/", "useGoogleAutoLogin": true, "useFacebookAutoLogin": true, "fbAppId": "136609459636", "fbApiVersion": "v3.2", "fbLanguageCode": "en_US", "ansFrontendEarlyPackageUrl": "https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-27-e7e745123d7df8b3.webpack", "stripePublishableKey": "pk_live_9MI7iqAKfs033l029FQIVsV3", "subdomainName": null, "subdomainSuffix": "quora.com", "reactTribeTabs": {"about": true, "main": true, "people": true, "submissions": true, "suggestions": true, "questions": true, "earnings": true, "stats": false, "settings": true, "quality": true, "admin_log": true, "details": false, "queue": true, "members_only": true}, "isClientSupported": true, "isOSSupported": true, "isOSDeprecated": false, "clientDeprecatedVersion": 0, "isAppUpgradeAvailable": false, "isAppDarkModeSupported": false, "defaultMobileAppTarget": null, "appTheme": null, "appUsesDeviceTheme": false, "moreStoriesTimeout": 90, "deviceOSSupportsDarkMode": false, "postUrlSuffix": "", "deviceTheme": null, "appCustomNavStyle": null, "nativePageContainer": null, "useMsgUpdateBadgeProperties": false, "shouldShowDarkModeToggleTooltip": false, "shouldSupportDarkModeNonNative": false, "i18nTranslationLoggingSampleRate": 0.1, "nativeSupportedSettings": {}, "shouldShowDarkModeToggles": false, "nativeToEnglishCharacterCountMultiplier": 1.0, "supportsLightWeightContentEditorToolbar": false, "showOldDarkModeAnnouncementCopy": false, "signupWallType": 4, "adReferralSignupSettings": {"isScrollToWall": false, "isReadMoreWall": false, "isInlineWall": false, "timeout": null, "isDismissible": false}, "specifiedTabsToPrefetch": [], "autoplayGifs": true, "supportsFloatingActionButtonForMessages": false, "isMobileAppPrefetched": false, "shouldRecordResponse": true, "requiresOldBrowserWarning": false};</script><script type="text/javascript">window.installSettings();</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};
         window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
         window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
         window.ansFrontendGlobals.data.inlineQueryResultsh.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
         window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
         window.ansFrontendGlobals.data.inlineQueryResults.results["eb7559536836f1916597ee60bf5dd5e69724c90b2efd896a1438bad151872fdf"] = "{\"data\":{\"question\":{\"pagedListDataConnection\":{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RDb25uZWN0aW9uQDA6OTk0MjM2\",\"__typename\":\"QuestionPagedListConnection\",\"adsData\":\"{\\\"answer_intervals\\\": [2, 3], \\\"ads\\\": [{\\\"ad_id\\\": null, \\\"query_id\\\": null}, {\\\"ad_id\\\": 211106235285492, \\\"query_id\\\": 1260919136423157794}, {\\\"ad_id\\\": 211106235960224, \\\"query_id\\\": 1260919136423157794}]}\",\"pageInfo\":{\"hasNextPage\":true,\"endCursor\":\"4\"},\"edges\":[{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjA=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"id\":\"UXVlc3Rpb25BZEl0ZW1AMDphZDpOb25lOjBmOTI1ZDQ0LWM3YTYtNDgxYi1iNmM0LTA0Yzc1ZmNhNzlkZg==\",\"__typename\":\"QuestionAdItem\",\"adLocation\":1,\"ad\":null},\"cursor\":\"0\"},{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjE=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"id\":\"UXVlc3Rpb25BbnN3ZXJIZWFkZXJJdGVtQDA6YW5zd2VySGVhZGVy\",\"__typename\":\"QuestionAnswerHeaderItem\",\"numAnswers\":101,\"question\":{\"id\":\"UXVlc3Rpb25AMDo5OTQyMzY=\",\"__typename\":\"Question\",\"qid\":994236,\"questionPageClusterVariant\":\"logged_in_rq_ranking\",\"showNoAnswersPrompt\":false,\"answerCount\":91,\"numOfLinkedTribes\":0}},\"cursor\":\"1\"},{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjI=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"answer\":{\"businessAnswer\":null,\"aid\":12664236,\"isDeleted\":false,\"content\":\"{\\\"sections\\\": [{\\\"spans\\\": [{\\\"text\\\": \\\"I'll write my experiences during the interview process, I've recently been interviewing (Mar - Apr 2015) and been very successful. Largely I've been asked two kinds of questions, background and technical.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Background Questions:\\\\n1. Walk me through your resume (or some variant thereof)\\\\n2. Explain your past PhD/scientific work\\\\n3. Which techniques (that are relevant for Data Science) did you use in that scientific work?\\\\n4. What languages are you familiar with?\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Technical Questions (In order of frequency of appearance):\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"1. Regression (the short answer here is to know everything) (Always)\\\\n- p-values, interpretation of coefficients, interaction coefficients\\\\n- know how factor variables are dummy coded, coefficient interpretation\\\\n- linear regression assumptions\\\\n- residual analysis, adding non-linear terms\\\\n- difference between L1 and L2 penalization, when you would use each one\\\\n- how to deal with highly correlated variables\\\\n- walk me through how you would approach building a regression model to predict Y given you have data X\\\\n- how do you choose the right number of predictors\\\\n- logistic regression\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"2. General predictive modeling (Always)\\\\n- train/test/validate sets, cross-validation, parameter selection, predictor selection, etc.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"3. Random Forrest (Always)\\\\n- how a tree is grown\\\\n- purpose of growing a forrest\\\\n- purpose of selecting a subset of variables at each split\\\\n- pruning\\\\n- variable importance\\\\n- knowing gbm here is also a plus\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"4. Matrix Factorization (Rare)\\\\n- pca, when do you use it? how are the components ordered?\\\\n- read up on how factorization was used in netflix competition\\\\n- i've never been asked about factor analysis, but it is great to know and makes other related questions easier\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"5. K-means clustering (often)\\\\n- what is the loss function? when does it converge?\\\\n- know the algorithm iteration steps\\\\n- how do you choose the right number of clusters?\\\\n- is the optimization convex?\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"6. Standard Stats (Often)\\\\n- t-test\\\\n- z-scores\\\\n- chi-square test\\\\n- know covariance and correlation equations\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"7. Time Series (Rare)\\\\n- p,d,q parameters and how you choose them\\\\n- unit root and box test\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"I've also been asked a series of increasingly difficult SQL queries in one interview.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Good Luck\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}]}\",\"questionPageImpressionHash\":\"answer_ranking|-1672131146\",\"viewerIsAuthor\":false,\"numDisplayComments\":2,\"viewer\":{\"canSeeDeletedContent\":false,\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"uid\":null,\"canReviewAnswers\":false,\"showJapanShareItems\":false},\"tribeItem\":null,\"id\":\"QW5zd2VyQDA6MTI2NjQyMzY=\",\"__typename\":\"Answer\",\"creationTime\":1432313675650206,\"updatedTime\":1432422895908836,\"author\":{\"id\":\"VXNlckAwOjIyMTAwMTE1Mw==\",\"__typename\":\"User\",\"uid\":221001153,\"isAnon\":true,\"profileImageUrl\":\"https://qsf.fs.quoracdn.net/-4-images.new_grid.profile_default_anonymous.png-26-a62b84947fe6f16f.png\",\"isVerified\":false,\"businessStatus\":null,\"profileUrl\":null,\"useTranslatedName\":true,\"names\":[{\"__typename\":\"UserName\",\"id\":\"VXNlck5hbWU6MjIxMDAxMTUzOkxBVE4=\",\"reverseOrder\":false,\"givenName\":\"Annalise\",\"familyName\":\"Cameron\",\"scriptCode\":\"LATN\"},{\"__typename\":\"UserName\",\"id\":\"VXNlck5hbWU6MjIxMDAxMTUzOkpQQU4=\",\"reverseOrder\":false,\"givenName\":\"Annalise\",\"familyName\":\"Cameron\",\"scriptCode\":\"JPAN\"}],\"adminNames\":[]},\"authorCredential\":null,\"isTranslated\":false,\"permaUrl\":\"/How-do-I-prepare-for-a-data-scientist-interview/answers/12664236\",\"isOwnTranslation\":false,\"debugInfo\":\"{}\",\"question\":{\"id\":\"UXVlc3Rpb25AMDo5OTQyMzY=\",\"__typename\":\"Question\",\"qid\":994236,\"url\":\"/How-do-I-prepare-for-a-data-scientist-interview\",\"title\":\"{\\\"sections\\\": [{\\\"spans\\\": [{\\\"text\\\": \\\"How do I prepare for a data scientist interview?\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}]}\",\"isPartnerQuestion\":false,\"asker\":{\"id\":\"VXNlckAwOjM2OTMw\",\"__typename\":\"User\",\"isEmployee\":false},\"debugInfo\":\"{}\",\"tribeItem\":null,\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"uid\":null},\"network\":{\"nid\":0,\"id\":\"TmV0d29yazow\"}
\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://alyaabbott.wordpress.com/2014/09/22/the-job-search-the-companys-objectives/\\\"}}}, {\\\"text\\\": \\\", I have just finished an extensive tech job search, which featured eight on-sites, along with countless phone screens and informal chats. I was interviewing for a combination of data science and software engineering (machine learning) positions, and I got a pretty good sense of what those interviews are like. In this post, I give an overview of what you should expect in a data science interview, and some suggestions for how to prepare.\\\", \\\"modifiers\\\": {\\\"italic\\\": true}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"An interview is not a pop quiz. You should know what to expect going in, and you can take the time to prepare for it. During the interview phase of the process, your recruiter is on your side and can usually tell you what types of interviews you\\\\u2019ll have. Even if the recruiter is reluctant to share that, common practices in the industry are a good guide to what you\\\\u2019re likely to see.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"In this post, I\\\\u2019ll go over the types of data science interviews I\\\\u2019ve encountered, and offer my advice on how to prepare for them. Data science roles generally fall into two broad ares of focus: statistics and machine learning. I only applied to the latter category, so that\\\\u2019s the type of position discussed in this post. My experience is also limited to tech companies, so I can\\\\u2019t offer guidance for data science in finance, biotech, etc..\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Here are the types of interviews (or parts of interviews) I\\\\u2019ve come across.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Always:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Coding (usually whiteboard)\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Applied machine learning\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Your background\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"\\\\nOften:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Culture fit\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Machine learning theory\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Dataset analysis\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Stats\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"\\\\nYou will encounter a similar set of interviews for a machine learning software engineering position, though more of the questions will fall in the coding category.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Coding (usually whiteboard)\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nThis is the same type of interview you\\\\u2019d have for any software engineering position, though the expectations may be less stringent. There are lots of \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"websites\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://steve-yegge.blogspot.com/2008/03/get-that-job-at-google.html\\\"}}}, {\\\"text\\\": \\\" and \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"books\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.amazon.com/Cracking-Coding-Interview-Programming-Questions/dp/098478280X/\\\"}}}, {\\\"text\\\": \\\" that will tell you how to prepare. Practice your coding skills if they\\\\u2019re rusty. Don\\\\u2019t forget to practice coding away from the computer (e.g. on paper), which is surely a skill that\\\\u2019s rusty. Review the data structures you may never have used outside of school \\\\u2014 binary search trees, linked lists, heaps. Be comfortable with recursion. Know how to reason about algorithm \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"running times\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://en.wikipedia.org/wiki/Time_complexity\\\"}}}, {\\\"text\\\": \\\". You can generally use any \\\\u201creal\\\\u201d language you want in an interview (Matlab doesn\\\\u2019t count, unfortunately); Python\\\\u2019s succinct syntax makes it \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"a great language for coding interviews\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"question\\\", \\\"qid\\\": 717847, \\\"url\\\": \\\"https://www.quora.com/Do-interviewers-frown-at-potential-hires-when-they-use-Ruby-or-Python-to-solve-an-interview-question-instead-of-C-C++-Java\\\"}}}, {\\\"text\\\": \\\".\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Prep tips:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"If you get nervous in interviews, try doing some practice problems under time pressure.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"If you don\\\\u2019t have much software engineering experience, see if you can get a friend to look over your practice code and provide feedback.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"During the interview:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Make sure you understand exactly what problem you\\\\u2019re trying to solve. Ask the interviewer questions if anything is unclear or underspecified.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Make sure you explain your plan to the interviewer before you start writing any code, so that they can help you avoid spending time going down less-than-ideal paths.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"If you can\\\\u2019t think of a good way to do something, it often helps to start by talking through a dumb way to do it.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Mention what invalid inputs you\\\\u2019d want to check for (e.g. input variable type check). Don\\\\u2019t bother writing the code to do so unless the interviewer asks. In all my interviews, nobody has ever asked.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Before declaring that your code is finished, think about variable initialization, end conditions, and boundary cases (e.g. empty inputs). If it seems helpful, run through an example. You\\\\u2019ll score points by catching your bugs yourself, rather than having the interviewer point them out.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"\\\\n\\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"Applied machine learning\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nAll the applied machine learning interviews I\\\\u2019ve had focused on \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"supervised learning\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://en.wikipedia.org/wiki/Supervised_learning\\\"}}}, {\\\"text\\\": \\\". The interviewer will present you with a prediction problem, and ask you to explain how you would set up an algorithm to make that prediction. The problem selected is often relevant to the company you\\\\u2019re interviewing at (e.g. figuring out which product to recommend to a user, which users are going to stop using the site, which ad to display, etc.), but can also be a toy example (e.g. recommending board games to a friend). This type of interview doesn\\\\u2019t depend on much background knowledge, other than having a general understanding of machine learning concepts (see below). However, it definitely helps to prepare by brainstorming the types of problems a particular company might ask you to solve. Even if you miss the mark, the brainstorming session will help with the culture fit interview (also see below).\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"When answering this type of question, I\\\\u2019ve found it helpful to start by laying out the setup of the problem. What are the inputs? What are the labels you\\\\u2019re trying to predict? What machine learning algorithms could you run on the data? Sometimes the setup will be obvious from the question, but sometimes you\\\\u2019ll need to figure out how to define the problem. In the latter case, you\\\\u2019ll generally have a discussion with the interviewer about some plausible definitions (e.g., what does it mean for a user to \\\\u201cstop using the site\\\\u201d?).\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"The main component of your answer will be feature engineering. There is nothing magical about brainstorming features. Think about what might be predictive of the variable you are trying to predict, and what information you would actually have available. I\\\\u2019ve found it helpful to give context around what I\\\\u2019m trying to capture, and to what extent the features I\\\\u2019m proposing reflect that information.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"For the sake of concreteness, here\\\\u2019s an example. Suppose Amazon is trying to figure out what books to recommend to you. (Note: I did not interview at Amazon, and have no idea what they actually ask in their interviews.) To predict what books you\\\\u2019re likely to buy, Amazon can look for books that are similar to your past Amazon purchases. But maybe some purchases were mistakes, and you vowed to never buy a book like that again. Well, Amazon knows how you\\\\u2019ve interacted with your Kindle books. If there\\\\u2019s a book you started but never finished, it might be a positive signal for general areas you\\\\u2019re interested in, but a negative signal for the particular author. Or maybe some categories of books deserve different treatment. For example, if a year ago you were buying books targeted at one-year-olds, Amazon could deduce that nowadays you\\\\u2019re looking for books for two-year-olds.  It\\\\u2019s easy to see how you can spend a while exploring the space between what you\\\\u2019d like to know and what you can actually find out.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Your background\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nYou should be prepared to give a high-level summary of your career, as well as to do a deep-dive into a project you\\\\u2019ve worked on. The project doesn\\\\u2019t have to be directly related to the position you\\\\u2019re interviewing for (though it can\\\\u2019t hurt), but it needs to be the kind of work you can have an in-depth technical discussion about.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"To prepare:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Review any papers/presentations that came out of your projects to refresh your mind on the technical details.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Practice explaining your project to a friend in order to make sure you are telling a coherent story. Keep in mind that you\\\\u2019ll probably be talking to someone who\\\\u2019s smart but doesn\\\\u2019t have expertise in your particular field.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Be prepared to answer questions as to why you chose the approach that you did, and about your individual contribution to the project.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"\\\\n\\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"Culture fit\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nHere are some culture fit questions your interviewers are likely to be interested in. These questions might come up as part of other interviews, and will likely be asked indirectly.  It helps to keep what the interviewer is looking for in the back of your mind.\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Are you specifically interested in the product/company/space you\\\\u2019d be working in?\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"It helps to prepare by thinking about the problems the company is trying to solve, and how you and the team you\\\\u2019d be part of could make a difference.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Do you care about impact?\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\" Even in a research-oriented corporate environment, I wouldn\\\\u2019t recommend saying that you don\\\\u2019t care about company metrics, and that you\\\\u2019d love to just play with data and write papers.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Will you work well with other people?\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\" I know it\\\\u2019s a clich\\\\u00e9, but most work is collaborative, and companies are trying to assess this as best they can. Avoid bad-mouthing former colleagues, and show appreciation for their contributions to your projects.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Are you willing to get your hands dirty?\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\" If there\\\\u2019s annoying work that needs to be done (e.g. cleaning up messy data), will you take care of it?\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Are you someone the team will be happy to have around on a personal level?\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\" Even though you might be stressed, try to be friendly, positive, enthusiastic and genuine throughout the interview process.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"You may also get broad questions about what kinds of work you enjoy and what motivates you. It\\\\u2019s useful to have an answer ready, but there may not be a \\\\u201cright\\\\u201d answer the interviewer is looking for.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Machine learning theory\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nThis type of interview will test your understanding of basic machine learning concepts, generally with a focus on \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"supervised learning\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://en.wikipedia.org/wiki/Supervised_learning\\\"}}}, {\\\"text\\\": \\\". You should understand:\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"The general setup for a supervised learning system\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Why you want to split data into training and test sets\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"The idea that models that aren\\\\u2019t powerful enough can\\\\u2019t capture the right generalizations about the data, and ways to address this (e.g. different model or projection into a higher-dimensional space)\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"The idea that models that are too powerful suffer from overfitting, and ways to address this (e.g. regularization)\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"You don\\\\u2019t need to know a lot of machine learning algorithms, but you definitely need to understand \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"logistic regression\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://en.wikipedia.org/wiki/Logistic_regression\\\"}}}, {\\\"text\\\": \\\", which seems to be what most companies are using. I also had some in-depth discussions of \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"SVMs\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://en.wikipedia.org/wiki/Support_vector_machine\\\"}}}, {\\\"text\\\": \\\", but that may just be because I brought them up.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Dataset analysis\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nIn this type of interview, you will be given a data set, and asked to write a script to pull out features for some prediction task. You may be asked to then plug the features into a machine learning algorithm. This interview essentially adds an implementation component to the applied machine learning interview (see above). Of course, your features may now be inspired by what you see in the data. Do the distributions for each feature you\\\\u2019re considering differ between the labels you\\\\u2019re trying to predict?\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"I found these interviews hardest to prepare for, because the recruiter often wouldn\\\\u2019t tell me what format the data would be in, and what exactly I\\\\u2019d need to do with it. (For example, do I need to review Python\\\\u2019s csv import module? Should I look over the syntax for training a model in scikit-learn?) I also had one recruiter tell me I\\\\u2019d be analyzing \\\\u201cbig data\\\\u201d, which was a bit intimidating (am I going to be working with distributed databases or something?) until I discovered at the interview that the \\\\u201cbig data\\\\u201d set had all of 11,000 examples. I encourage you to push for as much info as possible about what you\\\\u2019ll actually be doing.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"If you plan to use Python, working through the \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"scikit-learn tutorial\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.astroml.org/sklearn_tutorial/general_concepts.html\\\"}}}, {\\\"text\\\": \\\" is a good way to prepare.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Stats\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nI have a decent intuitive understanding of statistics, but very little formal knowledge. Most of the time, this sufficed, though I\\\\u2019m sure knowing more wouldn\\\\u2019t have hurt. You should understand how to set up an A/B test, including random sampling, confounding variables, summary statistics (e.g. mean), and measuring statistical significance.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Preparation Checklist & Resources\\\", \\\"modifiers\\\": {\\\"bold\\\": true}}, {\\\"text\\\": \\\"\\\\nHere is a summary list of tips for preparing for data science interviews, along with a few helpful resources.\\\\n\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"plain\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Coding (usually whiteboard)\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Get comfortable with basic algorithms, data structures and figuring out algorithm complexity.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Practice writing code away from the computer in your programming language of choice.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Resources:\\\", \\\"modifiers\\\": {\\\"italic\\\": true}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Pretty exhaustive list of what you might encounter in an interview\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://steve-yegge.blogspot.com/2008/03/get-that-job-at-google.html\\\"}}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Many interview prep books, e.g. \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"Cracking the Coding Interview\\\", \\\"modifiers\\\": {\\\"italic\\\": true, \\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.amazon.com/Cracking-Coding-Interview-Programming-Questions/dp/098478280X/\\\"}}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Applied machine learning\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Think about the machine learning problems that are relevant for each company you\\\\u2019re interviewing at. Use these problems as practice questions.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Your background\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Think through how to summarize your experience.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Prepare to give an in-depth technical explanation of a project you\\\\u2019ve worked on. Try it out on a friend.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Culture fit\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Think about the problems each company is trying to solve, and how you and the team you\\\\u2019d be part of could make a difference.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Be prepared to answer broad questions about what kind of work you enjoy and what motivates you.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Machine learning theory\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Understand machine learning concepts on an intuitive level, focusing especially on supervised learning.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Learn the math behind logistic regression.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Resources:\\\", \\\"modifiers\\\": {\\\"italic\\\": true}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"The Shape of Data\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://shapeofdata.wordpress.com/introduction/\\\"}}}, {\\\"text\\\": \\\" blog provides a nice intuitive overview.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"A Few Useful Things to Know about Machine Learning\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf\\\"}}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"To really go in depth, check out Andrew Ng\\\\u2019s Stanford machine learning course on \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"Coursera\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"https://www.coursera.org/course/ml\\\"}}}, {\\\"text\\\": \\\" or \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"OpenClassroom\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://openclassroom.stanford.edu/MainFolder/CoursePage.php?course=MachineLearning\\\"}}}, {\\\"text\\\": \\\".\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Dataset analysis\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Get comfortable with a set of technical tools for working with data.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Resources:\\\", \\\"modifiers\\\": {\\\"italic\\\": true}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"If you plan to use Python, work through the \\\", \\\"modifiers\\\": {}}, {\\\"text\\\": \\\"scikit-learn tutorial\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.astroml.org/sklearn_tutorial/general_concepts.html\\\"}}}, {\\\"text\\\": \\\" (you could skip section 2.4).\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Stats\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 0, \\\"quoted\\\": false, \\\"type\\\": \\\"ordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Get familiar with how to set up an A/B test.\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Resources:\\\", \\\"modifiers\\\": {\\\"italic\\\": true}}], \\\"indent\\\": 1, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Quora answer about how to prepare for interview questions about A/B testing\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"question\\\", \\\"qid\\\": 1486904, \\\"url\\\": \\\"https://www.quora.com/What-kind-of-A-B-testing-questions-should-I-expect-in-a-data-scientist-interview-and-how-should-I-prepare-for-such-questions\\\"}}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"How not to run an A/B test\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.evanmiller.org/how-not-to-run-an-ab-test.html\\\"}}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}, {\\\"spans\\\": [{\\\"text\\\": \\\"Sample size calculator\\\", \\\"modifiers\\\": {\\\"link\\\": {\\\"type\\\": \\\"url\\\", \\\"url\\\": \\\"http://www.evanmiller.org/ab-testing/sample-size.html\\\"}}}, {\\\"text\\\": \\\", which you can use to get some intuition about sample sizes required based on the sensitivity (i.e. minimal detectable effect) and statistical significance you\\\\u2019re looking for\\\", \\\"modifiers\\\": {}}], \\\"indent\\\": 2, \\\"quoted\\\": false, \\\"type\\\": \\\"unordered-list\\\", \\\"is_rtl\\\": false}]}\",\"questionPageImpressionHash\":\"answer_ranking|-257576531\",\"viewerIsAuthor\":false,\"numDisplayComments\":5,\"viewer\":{\"canSeeDeletedContent\":false,\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"uid\":
      </script><script type="text/javascript">window.setWebnodeLoadable({"css_tags":"<link as='style' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-main.css-27-a2ddb017b39ec896.css' /><link href='https://qsbr.fs.quoracdn.net/-4-main.css-27-a2ddb017b39ec896.css' rel='stylesheet' type='text/css' onerror='addAssetErr(this.href)' /><style type=\"text/css\">.Notif .kmohoozggnuggoumrenm{width:32px;height:32px}.Notif .photo_text_layout .notif_photo .kmohoozggnuggoumrenm{border-radius:3px}.Notif .photo_text_layout .notif_photo .kmohoozggnuggoumrenm{width:32px;height:32px}.Notif .photo_text_layout .notif_photo .kmohoozggnuggoumrenm .icon{display:inline-block}.SentIconNotif .kmohoozggnuggoumrenm{width:32px;height:32px;border-radius:3px}.PartnersSentNotif .kmohoozggnuggoumrenm{background:#c8dae6;height:32px;border-radius:3px}.PartnersAggregateSentNotif .kmohoozggnuggoumrenm{background:#c8dae6;height:32px;border-radius:3px}.PartnersSentNotif .kmohoozggnuggoumrenm .icon{margin:4px 0 0 4px;background:0}.PartnersAggregateSentNotif .kmohoozggnuggoumrenm .icon{margin:4px 0 0 4px;background:0}.feed_card_on .system_a2a_feed .system_a2a_header .jlwhhomvitkwhqucgkij{display:inline-block}.feed_card_on .system_a2a_feed .system_a2a_header .kmohoozggnuggoumrenm{background-color:#b92b27;display:flex;width:24px;height:24px;margin-right:8px;border-radius:3px}.feed_card_on .system_a2a_feed .system_a2a_header .kmohoozggnuggoumrenm .icon{width:12px;height:12px;background-size:12px 12px;background-image:url(//qsf.fs.quoracdn.net/-4-images.logo.icon_q_symbol.svg-26-10003b0c6b4bc952.svg);background-repeat:no-repeat;background-position:center center;margin:6px 0 0 6px}.HomeMultifeed .SuggestedAMAsBundle div.section_header .jlwhhomvitkwhqucgkij .header_text_main .ama_view_all_link{color:#949494;position:absolute;right:16px}.HomeMultifeed .SuggestedUsersBundle div.section_header .jlwhhomvitkwhqucgkij .header_text_main .ama_view_all_link{color:#949494;position:absolute;right:16px}.HomeMultifeed .SuggestedTopicsBundle div.section_header .jlwhhomvitkwhqucgkij .header_text_main .ama_view_all_link{color:#949494;position:absolute;right:16px}.WriteMain .WriteMultifeed .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm{display:inline-block;width:30px;height:30px}.WriteMain .WriteMultifeed .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon{vertical-align:-3px}.WriteMain .WriteMultifeed .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon:before{font-family:'q-icons';content:':)';font-style:normal;font-weight:normal;font-variant:normal;text-transform:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-shadow:1px 1px 1px rgba(0,0,0,0.004);text-rendering:optimizeLegibility!important;speak:none;color:#949494;font-size:24px;line-height:1;display:inline-block;width:24px;height:24px}.WriteMain .WriteMultifeed .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon:before{content:'\\F124'}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main{float:none;color:#333;font-weight:500;font-size:15px}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main .user{float:none;color:#333;font-weight:500;font-size:15px}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main a{color:#333}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main .user a{color:#333}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main a:hover{cursor:pointer}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_main .user a:hover{cursor:pointer}.WriteMain .WriteMultifeed .section_header .jlwhhomvitkwhqucgkij .header_text_details:first-letter {text-transform:capitalize}.follow_questions_header .jlwhhomvitkwhqucgkij{float:left}.Bundle .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm{display:inline-block;width:30px;height:30px}.Bundle .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon{vertical-align:-3px}.Bundle .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon:before{font-family:'q-icons';content:':)';font-style:normal;font-weight:normal;font-variant:normal;text-transform:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-shadow:1px 1px 1px rgba(0,0,0,0.004);text-rendering:optimizeLegibility!important;speak:none;color:#949494;font-size:24px;line-height:1;display:inline-block;width:24px;height:24px}.Bundle .edit_multifeed_link_wrapper .edit_multifeed_link .kmohoozggnuggoumrenm .icon:before{content:'\\F124'}.Bundle .section_header .jlwhhomvitkwhqucgkij{align-self:center;width:100%}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main{float:none;color:#333;font-weight:500;font-size:15px}.Bundle .section_header .jlwhhomvitkwhqucgkij .TopicNameSpan{float:none;color:#333;font-weight:500;font-size:15px}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main .user{float:none;color:#333;font-weight:500;font-size:15px}.Bundle .section_header .jlwhhomvitkwhqucgkij a.user{float:none;color:#333;font-weight:500;font-size:15px}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main a{color:#333}.Bundle .section_header .jlwhhomvitkwhqucgkij .TopicNameSpan a{color:#333}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main .user a{color:#333}.Bundle .section_header .jlwhhomvitkwhqucgkij a.user a{color:#333}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main a:hover{cursor:pointer}.Bundle .section_header .jlwhhomvitkwhqucgkij .TopicNameSpan a:hover{cursor:pointer}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_main .user a:hover{cursor:pointer}.Bundle .section_header .jlwhhomvitkwhqucgkij a.user a:hover{cursor:pointer}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_details{display:block;font-size:13px;text-transform:none;letter-spacing:0;font-weight:400;color:#949494}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_details a{color:#949494}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_details a:hover{cursor:pointer}.Bundle .section_header .jlwhhomvitkwhqucgkij .header_text_details:first-letter {text-transform:capitalize}.Bundle .section_header .kmohoozggnuggoumrenm{display:flex;width:24px;height:24px;margin-right:8px;border-radius:3px;align-self:center}.Bundle .section_header .kmohoozggnuggoumrenm svg,.Bundle .section_header .kmohoozggnuggoumrenm span{margin:auto}.section_header .kmohoozggnuggoumrenm .topic_photo_img{display:flex;width:30px;height:30px;margin-right:8px;border-radius:3px;display:inline-block}.section_header .kmohoozggnuggoumrenm .profile_photo_img{display:flex;width:30px;height:30px;margin-right:8px;border-radius:50%}.TopicPageLayout .tgiggycelxviokoggbdt{color:#333;font-weight:500;position:relative;border-bottom:1px solid #e2e2e2;margin-bottom:16px;padding-bottom:8px;font-size:18px;padding-bottom:7px;border-bottom:0}.TopicPageLayout .tgiggycelxviokoggbdt a{font-size:13px;font-weight:400;position:absolute;right:0;bottom:8px;color:#949494}.TopicPageLayout .tgiggycelxviokoggbdt a:hover{color:#949494;text-decoration:underline}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button{-webkit-user-select:none;-webkit-touch-callout:none;-moz-user-select:none;-ms-user-select:none;user-select:none;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;transition:opacity ease-in-out 100ms,color ease-in-out 100ms,background-color ease-in-out 100ms,border-color ease-in-out 100ms;border-radius:3px;box-shadow:0 1px 1px 0 rgba(200,200,200,0.2);display:inline-block;font-weight:500;outline:0;padding:3px 7px 4px 7px;text-align:center;text-decoration:none;cursor:pointer;background:#3e78ad;color:#fff;border:1px solid #3a66ad;box-shadow:0 1px 1px 0 rgba(200,200,200,0.6);font-weight:inherit;bottom:7px}.lang_ja .TopicPageLayout .tgiggycelxviokoggbdt a.action_button{font-weight:bold}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button:active{opacity:.6;box-shadow:none}.action_item .TopicPageLayout .tgiggycelxviokoggbdt a.action_button:active{opacity:1}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button:hover{text-decoration:none}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button .count{background:0;padding:0;margin:0;margin-left:6px;padding-left:6px;transition:opacity ease-in-out 100ms,color ease-in-out 100ms,background-color ease-in-out 100ms,border-color ease-in-out 100ms;position:relative;border-radius:0 3px 3px 0}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button .count:before{content:\"\";transition:opacity ease-in-out 100ms,color ease-in-out 100ms,background-color ease-in-out 100ms,border-color ease-in-out 100ms;width:1px;height:14.5px;position:absolute;left:0;top:2px}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button .no_count{display:none}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button.disabled{opacity:.5;pointer-events:none}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button.submit_button_disabled{opacity:.5;pointer-events:none}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button.fake_disabled{opacity:.5}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button.fake_disabled:hover{cursor:default}.action_item .TopicPageLayout .tgiggycelxviokoggbdt a.action_button{box-shadow:none;border:0}.action_item .TopicPageLayout .tgiggycelxviokoggbdt a.action_button:hover{border:0}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button:not(.fake_disabled):hover{border:1px solid #234462}.TopicPageLayout .tgiggycelxviokoggbdt a.action_button:not(.fake_disabled):focus{box-shadow:inset 1px 0 0 #fff,inset -1px 0 0 #fff,inset 0 1px 0 #fff,inset 0 -1px 0 #fff}.TopicPageLayout .tgiggycelxviokoggbdt .switcher{font-size:13px;color:#333;font-weight:400;position:absolute;right:0;bottom:8px}.TopicPageLayout .tgiggycelxviokoggbdt .switcher .current_item{font-weight:500}.TopicPageLayout .tgiggycelxviokoggbdt .switcher a{position:relative;color:#949494;bottom:auto}.TopicManagePageMain .tgiggycelxviokoggbdt.locked:after{left:inherit;margin-left:4px}.TopicOrganizePageMain .tgiggycelxviokoggbdt.locked:after{left:inherit;margin-left:4px}.modal_dismissible_signup_dialog .dialog_wrapper .signup_header .jlwhhomvitkwhqucgkij{position:relative;color:#666;letter-spacing:.5px;font-weight:300;font-size:19px}.modal_signup_dialog .dialog_wrapper .signup_header .jlwhhomvitkwhqucgkij{position:relative;color:#666;letter-spacing:.5px;font-weight:300;font-size:19px}.TopicDigestOptIn .jlwhhomvitkwhqucgkij{margin-left:12px}.ubjionrlfopfsmocisys .content_dismiss_title{font-size:15px;font-weight:500;margin-bottom:4px}.ubjionrlfopfsmocisys .content_dismiss_body{font-size:13px;color:#666}.EmailConfirmationModal .wrapper .jlwhhomvitkwhqucgkij{padding-top:16px;font-weight:bold;font-size:19px;display:block}.StatsMain .stats_side .ContentListWrapper .ContentListItem .tgiggycelxviokoggbdt{color:#949494}.StatsMain .stats_side .ContentListWrapper .ContentListItem.is_active .tgiggycelxviokoggbdt{color:#2b6dad}.PaidContributorSummary .tgiggycelxviokoggbdt{font-weight:bold}.PaidContributorPolicy .tgiggycelxviokoggbdt{font-weight:bold}.PaidContributorFAQ .tgiggycelxviokoggbdt{font-weight:bold}.PartnerPromptsPreviewCarousel .PreviewCarouselItem .kmohoozggnuggoumrenm{width:24px;height:24px;line-height:24px;border-radius:3px}.PartnersMain .prompt_bundle .header .kmohoozggnuggoumrenm{width:24px;height:24px;margin-right:8px;border-radius:3px}.PartnersPromptsMain .prompt_bundle .header .kmohoozggnuggoumrenm{width:24px;height:24px;margin-right:8px;border-radius:3px}.PartnersMain .prompt_bundle.A2APromptBundle .kmohoozggnuggoumrenm{background:#4b84e0}.PartnersPromptsMain .prompt_bundle.A2APromptBundle .kmohoozggnuggoumrenm{background:#4b84e0}.TribesInlineFollowSuggestionList .kmohoozggnuggoumrenm{margin-right:8px}.PaidAdminSummary .tgiggycelxviokoggbdt{font-weight:bold}.PaidAdminNDA .tgiggycelxviokoggbdt{font-weight:bold}.PaidAdminEarningsMain .tgiggycelxviokoggbdt{font-weight:bold}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .tgiggycelxviokoggbdt{font-size:18px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .cvcoomkuyenilgmthifa{margin-top:1px;right:20px;position:absolute}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk{display:flex;padding:4px 0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;display:block;font-weight:normal}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk:hover{text-decoration:underline}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .jlwhhomvitkwhqucgkij{display:flex;width:100%}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .kmohoozggnuggoumrenm{border-radius:3px;align-self:center;margin-right:8px;display:inline-block}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .kmohoozggnuggoumrenm .account_logo_img{background-size:cover;background-position:center;width:40px;height:40px;border-radius:100%}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .account_description{display:flex;width:100%}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .account_description .uaseszypcpbhzqrjtjps{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .uaseszypcpbhzqrjtjps{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-weight:500}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk .kzafykhovzthikopcnwn{font-size:13px;color:#949494}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .ijyhiqgvmsghmputcvxq{display:inline-block}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .mryrwmnzvdltvetyoqhj{height:1px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .ndfzxszvzldknyfxnysu{position:relative;bottom:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .cffiytzrcubbixbziyug{position:absolute;top:8px;right:8px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm{padding:16px 0 16px 0;margin:0 -16px;padding-top:4px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .wmxxrhpdoqjsbljwgrju{margin-top:4px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .wmxxrhpdoqjsbljwgrju .dxbyycyiwilyqffnagyr{box-shadow:inset 0 1px 0 rgba(0,0,0,0.05),inset 0 -1px 0 rgba(0,0,0,0.05),inset 1px 0 0 rgba(0,0,0,0.05),inset -1px 0 0 rgba(0,0,0,0.05);background-color:#fafafa;border-radius:3px;height:96px;width:180px;background-size:contain;background-repeat:no-repeat;background-position:center;margin-top:4px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .wmxxrhpdoqjsbljwgrju .dxbyycyiwilyqffnagyr.hhgtsvvqpseydxqymxgf{background-size:cover;background-position:center}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .wmxxrhpdoqjsbljwgrju .inegbzgwqknmbdcvbhqv{width:100%;height:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .qjxjhfdtutypwiamstwy{padding-right:8px;margin-bottom:8px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .qhqllqbybeufkuvlavjm{margin-bottom:0;padding:0 16px 0 16px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .cvcoomkuyenilgmthifa{padding-top:3px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .qhqllqbybeufkuvlavjm{margin-bottom:0;padding:0 16px 0 16px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .cvcoomkuyenilgmthifa{padding-top:3px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn{position:relative;margin-top:16px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .ijyhiqgvmsghmputcvxq{border-top:0;margin-bottom:4px;padding-top:0;display:inline-block}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .pkkztkhsdfnbxnyzsyxj{padding-top:16px;border-top:1px solid #e2e2e2;margin:0 -16px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .cffiytzrcubbixbziyug{position:absolute;top:8px;right:-8px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .cvcoomkuyenilgmthifa{right:0;margin-top:4px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .wmxxrhpdoqjsbljwgrju .ndfzxszvzldknyfxnysu{position:absolute;bottom:8px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .qhqllqbybeufkuvlavjm{margin:0;padding:0}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.jurogyxpcohfgzuhyjmn .rryioxbdjznehdnxusfk{margin:0}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd{position:relative;margin-top:16px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .ijyhiqgvmsghmputcvxq{border-top:0;margin-bottom:4px;padding-top:0;display:inline-block}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .pkkztkhsdfnbxnyzsyxj{padding-top:16px;border-top:1px solid #e2e2e2;margin:0 -16px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .cffiytzrcubbixbziyug{position:absolute;top:8px;right:-8px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .cvcoomkuyenilgmthifa{right:0;margin-top:4px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .wmxxrhpdoqjsbljwgrju .ndfzxszvzldknyfxnysu{position:absolute;bottom:8px}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .qhqllqbybeufkuvlavjm{margin:0;padding:0}.osnrbhuxavurwsuvlywn.feed_expand.gilhmnqixdtkflrrtziu.tyslfoticrlcoljzsotd .rryioxbdjznehdnxusfk{margin:0}.osnrbhuxavurwsuvlywn.question_page_content.gilhmnqixdtkflrrtziu .rryioxbdjznehdnxusfk{padding:12px 0 0 0;border-top:1px solid #e2e2e2;border-bottom:0}.osnrbhuxavurwsuvlywn.question_page_content.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm{margin:0;padding:8px 0 16px 0}.osnrbhuxavurwsuvlywn.question_page_content.gilhmnqixdtkflrrtziu .qhqllqbybeufkuvlavjm .qjxjhfdtutypwiamstwy{margin-bottom:8px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx{position:relative;margin-top:16px;margin-top:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .ijyhiqgvmsghmputcvxq{border-top:0;margin-bottom:4px;padding-top:0;display:inline-block}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .pkkztkhsdfnbxnyzsyxj{padding-top:16px;border-top:1px solid #e2e2e2;margin:0 -16px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .cffiytzrcubbixbziyug{position:absolute;top:8px;right:-8px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .cvcoomkuyenilgmthifa{right:0;margin-top:4px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .wmxxrhpdoqjsbljwgrju .ndfzxszvzldknyfxnysu{position:absolute;bottom:8px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .qhqllqbybeufkuvlavjm{margin:0;padding:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .pkkztkhsdfnbxnyzsyxj{padding:0;margin:0;border-top:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .cffiytzrcubbixbziyug{display:none}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .ijyhiqgvmsghmputcvxq{margin-bottom:0;width:100%}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk{width:100%;color:#333;font-size:15px;font-weight:500;border-bottom:1px solid #e2e2e2;padding-bottom:8px;margin-bottom:16px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .qjxjhfdtutypwiamstwy{padding:0;margin:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk{border-bottom:0;margin-bottom:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk .kmohoozggnuggoumrenm .account_logo_img{width:32px;height:32px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk{font-size:13px;padding-bottom:0}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk .kzafykhovzthikopcnwn{font-weight:400}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .content_flex{flex-direction:column}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .wmxxrhpdoqjsbljwgrju{margin-top:4px}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.rzhdygcseualpamolfgx .wmxxrhpdoqjsbljwgrju .dxbyycyiwilyqffnagyr{margin-bottom:8px;width:100%}.osnrbhuxavurwsuvlywn.gilhmnqixdtkflrrtziu.zkrnmotopudjvzpeotov .qjxjhfdtutypwiamstwy{margin-bottom:8px}.osnrbhuxavurwsuvlywn{display:inline-block;margin:16px 0 0 0;width:100%;overflow:inherit}.osnrbhuxavurwsuvlywn .ijyhiqgvmsghmputcvxq{font-size:13px;line-height:14px}.reset_qpage_type.osnrbhuxavurwsuvlywn .ijyhiqgvmsghmputcvxq{line-height:1.3125}.osnrbhuxavurwsuvlywn .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk{overflow:hidden;color:#949494;text-decoration:none;display:inline-block}.osnrbhuxavurwsuvlywn .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk:hover{text-decoration:underline}.osnrbhuxavurwsuvlywn .ijyhiqgvmsghmputcvxq .uaseszypcpbhzqrjtjps::first-letter {text-transform:capitalize}.osnrbhuxavurwsuvlywn .cffiytzrcubbixbziyug{position:absolute;right:-9px;top:-9px}.osnrbhuxavurwsuvlywn .rryioxbdjznehdnxusfk{position:relative}.osnrbhuxavurwsuvlywn .mighfimhndgceefwzngq{color:inherit;display:block;text-decoration:inherit;overflow:auto}.osnrbhuxavurwsuvlywn .tgiggycelxviokoggbdt{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-weight:bold;color:#333;text-decoration:inherit;line-height:23px;font-size:18px;margin-bottom:4px}.osnrbhuxavurwsuvlywn .tgiggycelxviokoggbdt:hover{text-decoration:underline}.reset_qpage_type.osnrbhuxavurwsuvlywn .tgiggycelxviokoggbdt{line-height:1.3125}.osnrbhuxavurwsuvlywn .qjxjhfdtutypwiamstwy{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;text-decoration:inherit;line-height:24px}.reset_qpage_type.osnrbhuxavurwsuvlywn .qjxjhfdtutypwiamstwy{line-height:1.3125}.body_14.reset_qpage_type.osnrbhuxavurwsuvlywn .qjxjhfdtutypwiamstwy{font-size:14px}.body_15.reset_qpage_type.osnrbhuxavurwsuvlywn .qjxjhfdtutypwiamstwy{font-size:15px}.osnrbhuxavurwsuvlywn .wmxxrhpdoqjsbljwgrju{position:relative;z-index:1}.osnrbhuxavurwsuvlywn .wmxxrhpdoqjsbljwgrju::after{clear:both;content:\" \";display:block}.osnrbhuxavurwsuvlywn .wmxxrhpdoqjsbljwgrju .cvcoomkuyenilgmthifa{position:absolute;right:0;top:50%;-webkit-transform:translate(0,-50%);-ms-transform:translate(0,-50%);transform:translate(0,-50%)}.osnrbhuxavurwsuvlywn .mryrwmnzvdltvetyoqhj .ndfzxszvzldknyfxnysu{color:#666;display:inline-block;position:relative;padding:8px 12px 8px 35px;font-size:14px;background-image:url(//qsf.fs.quoracdn.net/-4-images.ui.icons.external_link.svg-26-16775d22e28cd820.svg);background-repeat:no-repeat;background-position:8px center;background-size:24px;line-height:24px;font-weight:500;box-sizing:border-box;margin-left:-10px;margin-bottom:-12px}.osnrbhuxavurwsuvlywn .mryrwmnzvdltvetyoqhj .ndfzxszvzldknyfxnysu:hover{text-decoration:none;border-radius:40px;background-color:#fafafa}.osnrbhuxavurwsuvlywn .undo{color:#949494;text-decoration:none;font-size:13px;cursor:pointer}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.jurogyxpcohfgzuhyjmn{margin-top:0}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.jurogyxpcohfgzuhyjmn .ijyhiqgvmsghmputcvxq{margin-bottom:4px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.tyslfoticrlcoljzsotd{margin-top:0}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.tyslfoticrlcoljzsotd .ijyhiqgvmsghmputcvxq{margin-bottom:4px}.osnrbhuxavurwsuvlywn.bolgyfoxlzqmrpfemrby.tyslfoticrlcoljzsotd .tgiggycelxviokoggbdt{margin-bottom:4px;padding-bottom:0}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn{margin:16px 0 0 0}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn .rryioxbdjznehdnxusfk{margin:0 -16px}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn .rryioxbdjznehdnxusfk .ijyhiqgvmsghmputcvxq{border-top:1px solid #e2e2e2;padding:16px 16px 0 16px;margin-bottom:4px}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn .tgiggycelxviokoggbdt{display:inline-block;border-bottom:0;padding-bottom:0}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn .ubjionrlfopfsmocisys{border-top:1px solid #e2e2e2;padding-top:16px}.osnrbhuxavurwsuvlywn.feed_expand.jurogyxpcohfgzuhyjmn .cffiytzrcubbixbziyug{position:absolute;right:7px;top:7px}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd{margin:16px 0 0 0}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd .rryioxbdjznehdnxusfk{margin:0 -16px}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd .rryioxbdjznehdnxusfk .ijyhiqgvmsghmputcvxq{border-top:1px solid #e2e2e2;padding:16px 16px 0 16px;margin-bottom:4px}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd .tgiggycelxviokoggbdt{display:inline-block;border-bottom:0;padding-bottom:0}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd .ubjionrlfopfsmocisys{border-top:1px solid #e2e2e2;padding-top:16px}.osnrbhuxavurwsuvlywn.feed_expand.tyslfoticrlcoljzsotd .cffiytzrcubbixbziyug{position:absolute;right:7px;top:7px}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx{margin-top:0}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk{margin-bottom:16px;font-weight:500;border-bottom:1px solid #e2e2e2}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk{color:#333;font-size:15px;padding-bottom:8px}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk:hover{text-decoration:none}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx .tgiggycelxviokoggbdt{font-size:15px}.osnrbhuxavurwsuvlywn.rzhdygcseualpamolfgx .qjxjhfdtutypwiamstwy{font-size:14px;line-height:21px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .tgiggycelxviokoggbdt{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-size:16px;line-height:1.75;font-size:18px;line-height:28px;margin-bottom:0}.reset_qpage_type.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .tgiggycelxviokoggbdt{line-height:1.3125;margin-bottom:4px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .qjxjhfdtutypwiamstwy{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-size:16px;line-height:1.75;line-height:28px}.reset_qpage_type.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .qjxjhfdtutypwiamstwy{line-height:1.3125}.body_14.reset_qpage_type.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .qjxjhfdtutypwiamstwy{font-size:14px}.body_15.reset_qpage_type.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .qjxjhfdtutypwiamstwy{font-size:15px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .ndfzxszvzldknyfxnysu{color:#666;display:inline-block;position:relative;padding:8px 12px 8px 35px;font-size:14px;background-image:url(//qsf.fs.quoracdn.net/-4-images.ui.icons.external_link.svg-26-16775d22e28cd820.svg);background-repeat:no-repeat;background-position:8px center;background-size:24px;line-height:24px;font-weight:500;box-sizing:border-box;margin-left:-10px;margin-bottom:-12px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .ndfzxszvzldknyfxnysu:hover{text-decoration:none;border-radius:40px;background-color:#fafafa}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm .cffiytzrcubbixbziyug{display:none}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kqufhdmfctqjplbqkitc{margin:0 0 16px 0}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kqufhdmfctqjplbqkitc .ijyhiqgvmsghmputcvxq{border-top:1px solid #e2e2e2;border-bottom:0;padding-top:16px;margin-bottom:0}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre{margin-bottom:8px;margin-top:0}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .ijyhiqgvmsghmputcvxq{font-size:13px;line-height:14px;border-bottom:0;margin-bottom:0;border-top:1px solid #e2e2e2;padding-top:16px}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk{color:#949494;text-decoration:none;display:inline-block}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk:hover{text-decoration:none}.reset_qpage_type.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .ijyhiqgvmsghmputcvxq{line-height:1.3125}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .uaseszypcpbhzqrjtjps{color:#949494}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .tgiggycelxviokoggbdt{font-size:16px;line-height:28px}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .qjxjhfdtutypwiamstwy{font-size:16px;line-height:28px}.reset_qpage_type.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .tgiggycelxviokoggbdt{line-height:1.3125;font-size:18px}.body_14.reset_qpage_type.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .qjxjhfdtutypwiamstwy{line-height:1.3125;font-size:14px}.body_15.reset_qpage_type.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .qjxjhfdtutypwiamstwy{line-height:1.3125;font-size:15px}.osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre .ndfzxszvzldknyfxnysu{font-size:14px}.osnrbhuxavurwsuvlywn.regular_text .tgiggycelxviokoggbdt{font-size:15px;line-height:26px}.osnrbhuxavurwsuvlywn.regular_text .qjxjhfdtutypwiamstwy{font-size:15px;line-height:26px}.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .tgiggycelxviokoggbdt{line-height:1.3125}.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .qjxjhfdtutypwiamstwy{line-height:1.3125}.body_14.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .tgiggycelxviokoggbdt{font-size:14px}.body_14.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .qjxjhfdtutypwiamstwy{font-size:14px}.body_15.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .tgiggycelxviokoggbdt{font-size:15px}.body_15.reset_qpage_type.osnrbhuxavurwsuvlywn.regular_text .qjxjhfdtutypwiamstwy{font-size:15px}.logged_out .osnrbhuxavurwsuvlywn.czdzvmmqzslncfcpmlre{margin-top:0}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn{margin-top:0;background-color:#fff;padding-bottom:24px}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .rryioxbdjznehdnxusfk{margin-bottom:16px;font-weight:500;border-bottom:1px solid #e2e2e2}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk{color:#333;font-size:15px;padding-bottom:8px}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .rryioxbdjznehdnxusfk .nnzbdouayxegjfcnfawk:hover{text-decoration:none}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .tgiggycelxviokoggbdt{font-size:15px}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .qjxjhfdtutypwiamstwy{font-size:14px;line-height:21px}.osnrbhuxavurwsuvlywn.ehnbsafolrbtfgdylrfn .rryioxbdjznehdnxusfk{margin-bottom:12px}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi{margin-top:0}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi .ijyhiqgvmsghmputcvxq{margin-bottom:4px}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk:hover{text-decoration:none}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi.feed_expand:hover .rryioxbdjznehdnxusfk .ijyhiqgvmsghmputcvxq{border-color:#e2e2e2}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi.feed_expand .rryioxbdjznehdnxusfk{margin:0 -16px}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi.feed_expand .rryioxbdjznehdnxusfk .ijyhiqgvmsghmputcvxq{padding-left:16px;padding-right:16px;border-color:#efefef}.osnrbhuxavurwsuvlywn.kcdocowimwoxhkspfofi.feed_expand .cffiytzrcubbixbziyug{right:7px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc{padding-bottom:0;margin-bottom:0;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .sdonhelmxejekybeinoj:hover .promoted_answer_link{text-decoration:underline}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .AnswerBase{border-top:0;padding-top:0}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .AnswerHeader{margin-top:8px;z-index:51}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .question_title{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-weight:bold;line-height:23px;font-size:16px;color:#333}.body_14 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .question_title{line-height:1.3125;font-size:18px}.body_15 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .question_title{line-height:1.3125;font-size:18px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .ijyhiqgvmsghmputcvxq{color:#949494;z-index:51;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .sajoxloyuwatofuxpgot{position:absolute;top:0;left:0;bottom:0;right:0;z-index:50}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .sdonhelmxejekybeinoj:hover .promoted_answer_link{text-decoration:none}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.kqufhdmfctqjplbqkitc .AnswerBase{border-top:0;padding-top:4px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre{padding-bottom:0;margin-bottom:0;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .sdonhelmxejekybeinoj:hover .promoted_answer_link{text-decoration:underline}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .AnswerBase{border-top:0;padding-top:0}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .AnswerHeader{margin-top:8px;z-index:51}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .question_title{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-weight:bold;line-height:23px;font-size:16px;color:#333}.body_14 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .question_title{line-height:1.3125;font-size:18px}.body_15 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .question_title{line-height:1.3125;font-size:18px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .ijyhiqgvmsghmputcvxq{color:#949494;z-index:51;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .sajoxloyuwatofuxpgot{position:absolute;top:0;left:0;bottom:0;right:0;z-index:50}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.czdzvmmqzslncfcpmlre .question_title{display:block;margin-bottom:4px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn{padding-bottom:0;margin-bottom:0;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .sdonhelmxejekybeinoj:hover .promoted_answer_link{text-decoration:underline}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .AnswerBase{border-top:0;padding-top:0}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .AnswerHeader{margin-top:8px;z-index:51}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .question_title{font-family:-apple-system,BlinkMacSystemFont,\"Segoe UI\",Roboto,Oxygen-Sans,Ubuntu,Cantarell,\"Helvetica Neue\",sans-serif;font-weight:bold;line-height:23px;font-size:16px;color:#333}.body_14 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .question_title{line-height:1.3125;font-size:18px}.body_15 .osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .question_title{line-height:1.3125;font-size:18px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .ijyhiqgvmsghmputcvxq{color:#949494;z-index:51;position:relative}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .sajoxloyuwatofuxpgot{position:absolute;top:0;left:0;bottom:0;right:0;z-index:50}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .PromotedQuestionPageAnswer div{font-size:14px!important}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .ijyhiqgvmsghmputcvxq{margin-bottom:0;width:100%}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .ijyhiqgvmsghmputcvxq .nnzbdouayxegjfcnfawk{width:100%;color:#333;font-size:15px;font-weight:500;border-bottom:1px solid #e2e2e2;padding-bottom:8px;margin-bottom:8px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .question_title{display:block;margin-bottom:4px}.osnrbhuxavurwsuvlywn.kbzpvsacvckfthspzvzm.kcdocowimwoxhkspfofi.ehnbsafolrbtfgdylrfn .question_title span{font-size:15px;line-height:1.4}.LeadGenForm .kmohoozggnuggoumrenm{border-radius:3px;align-self:center;display:inline-block}.LeadGenFormSubmissionConfirmation .kmohoozggnuggoumrenm{border-radius:3px;align-self:center;display:inline-block}.LeadGenForm .kmohoozggnuggoumrenm .account_logo_img{background-size:cover;background-position:center;width:40px;height:40px;border-radius:100%}.LeadGenFormSubmissionConfirmation .kmohoozggnuggoumrenm .account_logo_img{background-size:cover;background-position:center;width:40px;height:40px;border-radius:100%}.zkrnmotopudjvzpeotov .mighfimhndgceefwzngq{cursor:pointer}.FeedStory .nrilhkgksvjqcyqwscxg{margin-bottom:-16px;width:calc(100% + 32px);margin-left:-16px;border-width:1px;border-color:#e2e2e2;border-radius:0;border-top-style:solid}.rzhdygcseualpamolfgx .nrilhkgksvjqcyqwscxg{margin-bottom:-16px;width:calc(100% + 32px);margin-left:-16px;border-width:1px;border-color:#e2e2e2;border-radius:0;border-top-style:solid}.zkrnmotopudjvzpeotov .qhqllqbybeufkuvlavjm{margin-bottom:16px}.zkrnmotopudjvzpeotov.kbzpvsacvckfthspzvzm .qhqllqbybeufkuvlavjm{margin-bottom:0}.zkrnmotopudjvzpeotov.kbzpvsacvckfthspzvzm .wmxxrhpdoqjsbljwgrju{display:flex}.zkrnmotopudjvzpeotov.kbzpvsacvckfthspzvzm .nrilhkgksvjqcyqwscxg{flex:1;margin-left:-12px}.ZapdosWall .jlwhhomvitkwhqucgkij{font-size:19px}</style>","html":"<div id='__w2_modal_container_'><div class='modal_overlay hidden' id='__w2_modal_overlay_'><div class='modal_wrapper normal' id='__w2_modal_wrapper_'></div></div></div><div id='wFUDYMDI1'></div><div id='wFUDYMDI3'></div><div class='__live_spinner hidden' id='__w2_wFUDYMDI7_loading'><div class='__live_spinner_indicator' id='__w2_wFUDYMDI7_spinner'></div></div><div class='PMsgContainer' id='__w2_wFUDYMDI8_pmsg_container'></div>","scripts":{"entry":"https://qsbr.fs.quoracdn.net/-4-web.entry.js.out-34-8f7d03da0b7a24ae.webpack","chunks":["https://qsbr.fs.quoracdn.net/-4-chunk.web.main.js.out-34-17a9aee2da9dc803.webpack"]},"js":{"settings":{"action":"q","actionTrail":null,"batchedServerCallUrl":"/webnode2/batched_server_call_POST","clientLogTrail":null,"componentInspector":false,"controller":"question","cookiePrefix":"m","debug":false,"enableFrameBusting":true,"fbLanguageCode":"en_US","formatted_tab_titles":{"feed":{"title":"Home"},"following":{"title":"Following"},"openqs":{"title":"Answer"},"notifs":{"title":"Notifications"},"more":{"title":"More"},"profile":{"title":"You"},"videos":{"title":"Videos"},"spaces":{"title":"Spaces"},"language":"en"},"formkey":"8899b542a65416db9195d943e35d34a1","googleClientId":"917071888555.apps.googleusercontent.com","googleCookiePolicy":"https://quora.com","instance":"main","interfaceLanguage":"en","interface_strings":{"ok":"OK","done":"Done","cancel":"Cancel","update":"Update","please_refresh":"Please refresh this page to receive new updates.","please_try_again":"Something went wrong. Please try again.","in_progress_warning":"Warning: Your work in progress has not been saved. Leaving or reloading this page will discard any unsaved changes.","trying_to_regain":"Trying to regain internet connection..."},"javascript_error_overlay":false,"datetime_strings":{"en":{"dayMonthTemplate":"{month} {day}","dayMonthYearTemplate":"{month} {day} {year}","monthNames":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"timeAbbrevs":["d","h","m","s"],"justNow":"just now","yesterday":"yesterday","agoTemplate":"{time} ago"},"es":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["Ene.","Feb.","Mar.","Abr.","May.","Jun.","Jul.","Ago.","Sept.","Oct.","Nov.","Dic."],"timeAbbrevs":["d","h","m","s"],"justNow":"justo ahora","yesterday":"ayer","agoTemplate":"hace {time}"},"fr":{"dayMonthTemplate":"le {day} {month}","dayMonthYearTemplate":"le {day} {month} {year}","monthNames":["janv.","f\u00e9vr.","mars","avr.","mai","juin","juil.","ao\u00fbt","sept.","oct.","nov.","d\u00e9c."],"timeAbbrevs":["d","h","m","s"],"justNow":"\u00e0 l'instant","yesterday":"hier","agoTemplate":"il y a {time}"},"de":{"dayMonthTemplate":"{day}. {month}","dayMonthYearTemplate":"{day}. {month} {year}","monthNames":["Jan","Feb","M\u00e4r","Apr","Mai","Jun","Jul","Aug","Sep","Okt","Nov","Dez"],"timeAbbrevs":["d","h","m","s"],"justNow":"Gerade eben","yesterday":"gestern","agoTemplate":"vor {time}"},"it":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["gen","feb","mar","apr","mag","giu","lug","ago","set","ott","nov","dic"],"timeAbbrevs":["d","h","m","s"],"justNow":"ora","yesterday":"ieri","agoTemplate":"{time} fa"},"ja":{"dayMonthTemplate":"{month} {day}","dayMonthYearTemplate":"{month} {day} {year}","monthNames":["1\u6708","2\u6708","3\u6708","4\u6708","5\u6708","6\u6708","7\u6708","8\u6708","9\u6708","10\u6708","11\u6708","12\u6708"],"timeAbbrevs":["\u65e5","\u6642\u9593","\u5206","\u79d2"],"justNow":"\u305f\u3063\u305f\u4eca","yesterday":"\u6628\u65e5","agoTemplate":"{time}\u524d"},"id":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["Jan","Feb","Mar","Apr","Mei","Jun","Jul","Agt","Sep","Okt","Nov","Des"],"timeAbbrevs":["d","h","m","s"],"justNow":"baru saja","yesterday":"kemarin","agoTemplate":"{time} lalu"},"pt":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["jan","fev","mar","abr","mai","jun","jul","ago","set","out","nov","dez"],"timeAbbrevs":["d","h","m","s"],"justNow":"agora h\u00e1 pouco","yesterday":"ontem","agoTemplate":"{time} atr\u00e1s"},"hi":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["\u091c\u0928","\u092b\u093c\u0930","\u092e\u093e\u0930\u094d\u091a","\u0905\u092a\u094d\u0930\u0948","\u092e\u0908","\u091c\u0942\u0928","\u091c\u0941\u0932\u093e","\u0905\u0917","\u0938\u093f\u0924\u0902","\u0905\u0915\u094d\u091f\u0942","\u0928\u0935\u0902","\u0926\u093f\u0938\u0902"],"timeAbbrevs":["d","h","m","s"],"justNow":"\u0905\u092d\u0940-\u0905\u092d\u0940","yesterday":"\u0915\u0932","agoTemplate":"{time} \u092a\u0939\u0932\u0947"},"nl":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["jan","feb","mrt","apr","mei","jun","jul","aug","sep","okt","nov","dec"],"timeAbbrevs":["d","u","m","s"],"justNow":"zojuist","yesterday":"gisteren","agoTemplate":"{time} geleden"},"da":{"dayMonthTemplate":"{day}. {month}","dayMonthYearTemplate":"{day}. {month} {year}","monthNames":["jan","feb","mar","apr","maj","jun","jul","aug","sep","okt","nov","dec"],"timeAbbrevs":["d","t","m","s"],"justNow":"lige nu","yesterday":"i g\u00e5r","agoTemplate":"For {time} siden"},"fi":{"dayMonthTemplate":"{day}. {month}","dayMonthYearTemplate":"{day}. {month} {year}","monthNames":["tammi","helmi","maalis","huhti","touko","kes\u00e4","hein\u00e4","elo","syys","loka","marras","joulu"],"timeAbbrevs":["vrk","t","m","s"],"justNow":"juuri nyt","yesterday":"eilen","agoTemplate":"{time} sitten"},"no":{"dayMonthTemplate":"{day}. {month}","dayMonthYearTemplate":"{day}. {month} {year}","monthNames":["jan","feb","mar","apr","mai","jun","jul","aug","sep","okt","nov","des"],"timeAbbrevs":["d","t","m","s"],"justNow":"akkurat n\u00e5","yesterday":"i g\u00e5r","agoTemplate":"for {time} siden"},"sv":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month}, {year}","monthNames":["Jan","Feb","Mar","Apr","Maj","Jun","Jul","Aug","Sep","Okt","Nov","Dec"],"timeAbbrevs":["d","h","m","s"],"justNow":"just nu","yesterday":"i g\u00e5r","agoTemplate":"{time} sedan"},"mr":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["\u091c\u093e\u0928\u0947","\u092b\u0947\u092c\u094d\u0930\u0941","\u092e\u093e\u0930\u094d\u091a","\u090f\u092a\u094d\u0930\u093f","\u092e\u0947","\u091c\u0942\u0928","\u091c\u0941\u0932\u0948","\u0911\u0917","\u0938\u092a\u094d\u091f\u0947\u0902","\u0911\u0915\u094d\u091f\u094b","\u0928\u094b\u0935\u094d\u0939\u0947\u0902","\u0921\u093f\u0938\u0947\u0902"],"timeAbbrevs":["d","h","m","s"],"justNow":"\u0906\u0924\u093e\u091a","yesterday":"\u0915\u093e\u0932","agoTemplate":"{time}\u092a\u0942\u0930\u094d\u0935\u0940"},"bn":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["\u099c\u09be\u09a8\u09c1\u09af\u09bc\u09be\u09b0\u09c0","\u09ab\u09c7\u09ac\u09cd\u09b0\u09c1\u09af\u09bc\u09be\u09b0\u09c0","\u09ae\u09be\u09b0\u09cd\u099a","\u098f\u09aa\u09cd\u09b0\u09bf\u09b2","\u09ae\u09c7","\u099c\u09c1\u09a8","\u099c\u09c1\u09b2\u09be\u0987","\u0986\u0997\u09b8\u09cd\u099f","\u09b8\u09c7\u09aa\u09cd\u099f\u09c7\u09ae\u09cd\u09ac\u09b0","\u0985\u0995\u09cd\u099f\u09cb\u09ac\u09b0","\u09a8\u09ad\u09c7\u09ae\u09cd\u09ac\u09b0","\u09a1\u09bf\u09b8\u09c7\u09ae\u09cd\u09ac\u09b0"],"timeAbbrevs":["d","h","m","s"],"justNow":"\u098f\u0996\u09c1\u09a8\u09bf","yesterday":"\u0997\u09a4\u0995\u09be\u09b2","agoTemplate":"{time} \u0986\u0997\u09c7"},"ta":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":["\u0b9c\u0ba9.","\u0baa\u0bbf\u0baa\u0bcd.","\u0bae\u0bbe\u0bb0\u0bcd.","\u0b8f\u0baa\u0bcd.","\u0bae\u0bc7","\u0b9c\u0bc2\u0ba9\u0bcd","\u0b9c\u0bc2\u0bb2\u0bc8","\u0b86\u0b95.","\u0b9a\u0bc6\u0baa\u0bcd.","\u0b85\u0b95\u0bcd.","\u0ba8\u0bb5.","\u0b9f\u0bbf\u0b9a."],"timeAbbrevs":["\u0ba8\u0bbe","\u0bae","\u0ba8\u0bbf","\u0ba8\u0bca"],"justNow":"\u0b9a\u0bb1\u0bcd\u0bb1\u0bc1 \u0bae\u0bc1\u0ba9\u0bcd","yesterday":"\u0ba8\u0bc7\u0bb1\u0bcd\u0bb1\u0bc1","agoTemplate":"{time} \u0bae\u0bc1\u0ba9\u0bcd\u0baa\u0bc1"},"ar":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month} {year}","monthNames":
{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month}, {year}","monthNames":["\u0d1c\u0d28\u0d41","\u0d2b\u0d46\u0d2c\u0d4d\u0d30\u0d41","\u0d2e\u0d3e\u0d7c","\u0d0f\u0d2a\u0d4d\u0d30\u0d3f","\u0d2e\u0d47\u0d2f\u0d4d","\u0d1c\u0d42\u0d7a","\u0d1c\u0d42\u0d32\u0d48","\u0d13\u0d17","\u0d38\u0d46\u0d2a\u0d4d\u0d31\u0d4d\u0d31\u0d02","\u0d12\u0d15\u0d4d\u0d1f\u0d4b","\u0d28\u0d35\u0d02","\u0d21\u0d3f\u0d38\u0d02"],"timeAbbrevs":["d","h","m","s"],"justNow":"\u0d07\u0d2a\u0d4d\u0d2a\u0d4b\u0d7e","yesterday":"\u0d07\u0d28\u0d4d\u0d28\u0d32\u0d46","agoTemplate":"{time} \u0d2e\u0d41\u0d2e\u0d4d\u0d2a\u0d4d"},"te":{"dayMonthTemplate":"{month} {day}","dayMonthYearTemplate":"{year} {month} {day}","monthNames":["\u0c1c\u0c28","\u0c2b\u0c3f\u0c2c\u0c4d\u0c30","\u0c2e\u0c3e\u0c30\u0c4d\u0c1a\u0c3f","\u0c0f\u0c2a\u0c4d\u0c30\u0c3f","\u0c2e\u0c47","\u0c1c\u0c42\u0c28\u0c4d","\u0c1c\u0c41\u0c32\u0c48","\u0c06\u0c17\u0c38\u0c4d\u0c1f\u0c41","\u0c38\u0c46\u0c2a\u0c4d\u0c1f\u0c46\u0c02","\u0c05\u0c15\u0c4d\u0c1f\u0c4b","\u0c28\u0c35\u0c02","\u0c21\u0c3f\u0c38\u0c46\u0c02"],"timeAbbrevs":["d","h","m","s"],"justNow":"\u0c07\u0c2a\u0c4d\u0c2a\u0c41\u0c21\u0c47","yesterday":"\u0c28\u0c3f\u0c28\u0c4d\u0c28","agoTemplate":"{time} \u0c15\u0c4d\u0c30\u0c3f\u0c24\u0c02"},"pl":{"dayMonthTemplate":"{day} {month}","dayMonthYearTemplate":"{day} {month}, {year}","monthNames":["sty","lut","mar","kwi","maj","cze","lip","sie","wrz","pa\u017a","lis","gru"],"timeAbbrevs":["d","h","m","s"],"justNow":"przed chwil\u0105","yesterday":"wczoraj","agoTemplate":"{time} temu"}},"isAnonPage":false,"isCrawler":false,"isLoggedIn":false,"isReactIframe":false,"isParallel":true,"isExpandedBroadcast":true,"logComponentTime":false,"networkOptions":{"enableSmartQuotes":true},"nid":0,"uid":null,"nidToSubdomainMap":{"0":null,"5":"es","6":"fr","7":"de","8":"it","9":"jp","10":"id","11":"pt","12":"hi","13":"nl","14":"da","15":"fi","16":"no","17":"sv","18":"mr","19":"bn","20":"ta","21":"ar","22":"he","23":"gu","24":"kn","25":"ml","26":"te","27":"pl"},"request_id":"db766a570bf9436fa501c1051b4cb627","revision":"0a952343942873c97a141835dd3c2fd0dd7d4244","postUrlSuffix":"","serverCallUrl":"/webnode2/server_call_POST","subdomain_of_network":null,"subdomain_name":null,"subdomain_suffix":"quora.com","stripePublishableKey":"pk_live_9MI7iqAKfs033l029FQIVsV3","shouldReportE2E":false,"useScaledInference":true,"cdn":"fastly","fbApiVersion":"v3.2","onloadDelay":0,"qtextData":{"videoEnabled":true,"videoEditorSupported":false,"deleteVideoSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.delete.svg-26-c5a6a52657cca97c.svg","playVideoSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.play.svg-26-4dcf69b1e7c1cab8.svg","videoIndicatorSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.film.svg-26-02a4fdc75a080e30.svg","videoNotPresentSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.video_not_present.svg-26-2d1d24366496b950.svg","deleteVideoTitle":"Are you sure you want to delete your video?","deleteVideoMessage":"All related video clips will be deleted permanently.","deleteVideoButton":"Delete","cantSubmitVideo":"Submit your answer from the device the video was originally created, or delete the video to continue submission.","videosStillUploading":"Videos are still uploading.","videosStillUploadingAnotherAnswer":"Videos are still uploading from other answers.","videoNotPresent":"Your video is on a different device. You can edit your video from the device it was created.","uploadingSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.video_uploading.svg-26-2cd8478673cc20e9.svg","uploadErrorSvg":"https://qsf.fs.quoracdn.net/-4-images.icons.video_player.notif_submission_failed.svg-26-d49277fcd0aab5f1.svg","pauseUploadingTitle":"Uploading","doneUploadingTitle":"Uploaded","resumeUploadingTitle":"Upload Paused","uploadErrorTitle":"Something went wrong","pauseUploadingButton":"Pause","resumeUploadingButton":"Resume Uploading","retryUploadingButton":"Retry","unsavedVideosMsg":"Video uploading."},"pageIsMobile":false,"postkey":"e44d968b1d96e9040a8dd991a67080d6","speedStandard":{},"pageMode":"post_reload","fbAppId":"136609459636","androidAppPackageName":"com.quora.android","force_use_absolute_links":false,"windowId":"react_vpopiagoqpmcidij"},"gatings":{"ad_unit_field_length_limits":{"business_name":40,"business_description":1024,"business_display_name":40,"title":65,"content_text":105,"url":1024,"domain_name":30,"tax_id":32},"enable_ad_placement_targeting":false,"enable_gender_targeting_ui":true,"qfeed_log_debugger":false,"force_mobile_app_modals":null,"show_native_console_log":false,"android_debuggable":false,"send_unsplash_tracking_in_js":false,"console_log_js_messages":[],"broadcast_debug_mode":false,"broadcast_debug_filters":{"cid_filter":[],"dependency_filter":[]},"use_native_selection":false,"use_log_subdomain_for_log_sender":true,"client_side_batched_logging_interval":2000,"async_navigate_to_js":true,"qualtrics_development_mode":false,"speed_index_sampling_rate":0,"qualtrics_zone_codes":["4TKR5tYyBOyKSO1"],"enable_mobile_bug_report_by_shake_gesture":false,"multimodal_remove_proxy":false,"multimodal_remove_android_hack":false,"fix_body_styles_new":true,"broadcast_enabled":true,"verbose_client_logging_categories":[]},"window_q":{"errorSamplingRate":1.0,"revision":"0a952343942873c97a141835dd3c2fd0dd7d4244","subdomainSuffix":"quora.com"},"window_globals":{"isWebnodePage":false,"isWebnodeLoaded":true,"ansWebWebpack
://www.quora.com/How-do-I-prepare-for-a-data-scientist-interview"},{}],["view/livenode","LiveSpinner","wFUDYMDI7","",{},{}],["unified_view/pmsg","PMsgContainer","wFUDYMDI8","",{},{}],["unified_view/service_worker","Installer","wFUDYMDI9","",{},{}],["unified_view/gif_player","QTextGIFPlayer","wFUDYMDI10","",{},{}]],true]}});</script><script type="text/javascript">window.setTimingData({"server_time":374.645,"webnode_loadable_render_time":50.564,"query_time":334.359,"head_script_time":13.347,"total_worker_time":1182.928,"window_id":"react_vpopiagoqpmcidij","page":374.645,"request":379.863,"experiments":"","envs":""});
         window.reportPageSpeedData({"standard":{}});
      </script><script type="text/javascript">var isHttps="https:"==window.location.protocol,serviceWorkersSupported="serviceWorker"in window.navigator;isHttps&&serviceWorkersSupported&&window.addEventListener("load",function(){setTimeout(function(){window.navigator.serviceWorker.register("/sw.js").then(function(e){e.update()})},100)});</script>
   </body>
</html>
"""

# %%
# display HTML string in the jupyter notebook
from IPython.core.display import display, HTML
display(HTML(html_string))
# Out:
# <!DOCTYPE html>
# <html lang='en' dir='ltr' style='padding: 0; margin: 0;'>
#    <head>
#       <meta http-equiv='Content-Type' content='text/html; charset=utf-8' />
#       <link rel='icon' href='https://qsf.fs.quoracdn.net/-4-images.favicon.ico-26-ebf6a9e7f7b4576d.ico' />
#       <title>How to prepare for a data scientist interview - Quora</title>
#       <meta name="robots" content="noarchive" />
#       <meta name='twitter:widgets:theme' content='light' />
#       <link rel='canonical' href='https://www.quora.com/How-do-I-prepare-for-a-data-scientist-interview' />
#       <link as='script' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ac99ceb1b9c10014.webpack' />
#       <link as='script' rel='preload' href='https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-15b26220d3ee4250.webpack' />
# ...

# %%
# use BeautifulSoup
ps = BeautifulSoup(html_string)
print(ps)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" style="padding: 0; margin: 0;">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://qsf.fs.quoracdn.net/-4-images.favicon.ico-26-ebf6a9e7f7b4576d.ico" rel="icon"/>
# <title>How to prepare for a data scientist interview - Quora</title>
# <meta content="noarchive" name="robots"/>
# <meta content="light" name="twitter:widgets:theme"/>
# <link href="https://www.quora.com/How-do-I-prepare-for-a-data-scientist-interview" rel="canonical"/>
# <link as="script" href="https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-common-27-ac99ceb1b9c10014.webpack" rel="preload"/>
# <link as="script" href="https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-15b26220d3ee4250.webpack" rel="preload"/>
# <link as="script" href="https://qsbr.fs.quoracdn.net/-4-ans_frontend-relay-vendor-27-847dd7e3d7f6b8cc.webpack" rel="preload"/>
# ...

# %%
#use name parameter to select by tag names
body = ps.find(name="body")
print(body)
# Out:
# <body class="q-platform--desktop" style="margin: 0;padding: 0;">
# <div id="root"></div>
# <noscript>Please enable Javascript and refresh the page to continue</noscript>
# <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};
#          window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
#          window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
#          window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
#          window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
# ...

# %%
print(html_string.find(name="title").text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2ccbf007f125> in <module>
# ----> 1 print(html_string.find(name="title").text)
#
# TypeError: find() takes no keyword arguments
